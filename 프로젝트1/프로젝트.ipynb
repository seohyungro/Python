# %%
import pandas as pd
import numpy as np

# %%
kospi_1 = pd.read_csv("./거시경제변수데이터/코스피200_사업보고서연결.csv", encoding = "euc-kr")
kospi_2 = pd.read_csv("./거시경제변수데이터/코스피200_사업보고서개별.csv", encoding = "euc-kr")
kospi_3 = pd.read_csv("./거시경제변수데이터/코스피200_반기보고서연결.csv", encoding = "euc-kr")
kospi_4 = pd.read_csv("./거시경제변수데이터/코스피200_반기보고서개별.csv", encoding = "euc-kr")
kospi1 = pd.read_csv("./거시경제변수데이터/코200_사업보고서연결.csv", encoding = "euc-kr")
kospi2 = pd.read_csv("./거시경제변수데이터/코200_사업보고서개별.csv", encoding = "euc-kr")
k1 = pd.read_csv("./거시경제변수데이터/반기종가.csv")
k2 = pd.read_csv("./거시경제변수데이터/전기종가.csv")

# %%
k2.columns = ['Unnamed: 0', '거래소코드', '종목명', '회계년도', '종가']

# %%
k2['거래소코드'] = k2['거래소코드'].astype(str).str.zfill(6)

# %%
k2
# Out:
#       Unnamed: 0   거래소코드        종목명     회계년도      종가
# 0              0  005930       삼성전자  2007/12  556000
# 1              1  005490      POSCO  2007/12  575000
# 2              2  009540      현대중공업  2007/12  442500
# 3              3  015760       한국전력  2007/12   39650
# 4              4  060000       국민은행  2007/12   69000
# ...          ...     ...        ...      ...     ...
# 3196         195  105630       한세실업  2022/12   15400
# 3197         196  241590   화승엔터프라이즈  2022/12    9230
# 3198         197  284740      쿠쿠홈시스  2022/12   29400
# 3199         198  294870  HDC현대산업개발  2022/12   10000
# 3200         199  057050      현대홈쇼핑  2022/12   53900
#
# [3201 rows x 5 columns]

# %%
kospi1['회사명'].unique()
# Out:
# array(['(주)BNK금융지주', '(주)DB하이텍', '(주)JB금융지주', '(주)KB금융지주', '(주)강원랜드',
#        '(주)녹십자', '(주)녹십자홀딩스', '(주)농심', '(주)대우건설', '(주)대웅', '(주)대웅제약',
#        '(주)대한항공', '(주)더블유게임즈', '(주)동서', '(주)두산', '(주)메리츠금융지주', '(주)보령',
#        '(주)비지에프리테일', '(주)셀트리온', '(주)신세계', '(주)신세계인터내셔날', '(주)신한금융지주회사',
#        '(주)아모레퍼시픽', '(주)아모레퍼시픽그룹', '(주)에스원', '(주)에프앤에프', '(주)엔씨소프트',
#        '(주)엘에스', '(주)엘엑스인터내셔널', '(주)엘지', '(주)엘지생활건강', '(주)엘지에너지솔루션',
#        '(주)엘지유플러스', '(주)엘지화학', '(주)영원무역', '(주)영풍', '(주)오뚜기', '(주)오리온',
#        '(주)오리온홀딩스', '(주)우리금융지주', '(주)유한양행', '(주)이마트', '(주)제일기획', '(주)종근당',
#        '(주)지누스', '(주)지에스', '(주)지에스리테일', '(주)카카오', '(주)카카오뱅크', '(주)카카오페이',
#        '(주)케이씨씨', '(주)케이티', '(주)케이티앤지', '(주)크래프톤', '(주)포스코인터내셔널',
#        '(주)포스코퓨처엠', '(주)풍산', '(주)하나금융지주', '(주)하나투어', '(주)하이브', '(주)한샘',
#        '(주)한섬', '(주)한솔케미칼', '(주)한진칼', '(주)한화', '(주)현대미포조선', '(주)현대백화점',
#        '(주)현대지에프홀딩스', '(주)현대홈쇼핑', '(주)호텔신라', '(주)화승엔터프라이즈', '(주)효성',
# ...

# %%
kospi2.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[제조]정상영업이익증가율(IFRS)', '[제조]순이익증가율(IFRS)',
#        '[제조]1주당순이익(IFRS)', '[제조]부채비율(IFRS)', '[제조]매출액정상영업이익률(IFRS)',
#        '[제조]매출액증가율(IFRS)', '[제조]1주당 CASH FLOW(IFRS)', '[제조]1주당순자산(IFRS)',
#        '[제조]PER(최고)(IFRS)', '[제조]PER(최저)(IFRS)', '[제조]PBR(최고)(IFRS)',
#        '[제조]PBR(최저)(IFRS)', '[제조]PCR(최고)(IFRS)', '[제조]PCR(최저)(IFRS)'],
#       dtype='object')

# %%
kospi1.columns = ['회사명', '거래소코드', '회계년도', '정상영업이익증가율', '순이익증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '매출액증가율', '1주당 CASH FLOW', '1주당순자산', 'PER(최고)', 'PER(최저)', 'PBR(최고)', 'PBR(최저)', 'PCR(최고)', 'PCR(최저)']
kospi2.columns = ['회사명', '거래소코드', '회계년도', '정상영업이익증가율', '순이익증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '매출액증가율', '1주당 CASH FLOW', '1주당순자산', 'PER(최고)', 'PER(최저)', 'PBR(최고)', 'PBR(최저)', 'PCR(최고)', 'PCR(최저)']

# %%
kospi1.isna().sum()
# Out:
# 회사명                 0
# 거래소코드               0
# 회계년도                0
# 정상영업이익증가율         576
# 순이익증가율            576
# 1주당순이익            576
# 부채비율              576
# 매출액정상영업이익률        576
# 매출액증가율            576
# 1주당 CASH FLOW     576
# 1주당순자산           2830
# PER(최고)           397
# PER(최저)           397
# PBR(최고)           397
# PBR(최저)           397
# PCR(최고)           397
# PCR(최저)           397
# dtype: int64

# %%
kospi = kospi1.fillna(kospi2)

# %%
# kospi = pd.concat([kospi, kospi_], axis=1)
# kospii = pd.concat([kospii, kospi__], axis=1)

# %%
kospi = kospi.reset_index(drop=True)

# %%
len(kospi["회사명"].unique())
# Out:
# 200

# %%
kospi["PER"] = (kospi["PER(최고)"] + kospi["PER(최저)"])/2
kospi["PBR"] = (kospi["PBR(최고)"] + kospi["PBR(최저)"])/2
kospi["PCR"] = (kospi["PCR(최고)"] + kospi["PCR(최저)"])/2

# %%
kospi.drop(["PER(최고)", "PER(최저)", "PBR(최고)", "PBR(최저)", "PCR(최고)", "PCR(최저)"], axis=1, inplace=True)

# %%
kospi
# Out:
#              회사명   거래소코드     회계년도  정상영업이익증가율  순이익증가율    1주당순이익    부채비율
# 0     (주)BNK금융지주  138930  2011/12        NaN     NaN       NaN     NaN  \
# 1     (주)BNK금융지주  138930  2012/12        NaN     NaN       NaN     NaN
# 2     (주)BNK금융지주  138930  2013/12        NaN     NaN       NaN     NaN
# 3     (주)BNK금융지주  138930  2014/12        NaN     NaN       NaN     NaN
# 4     (주)BNK금융지주  138930  2015/12        NaN     NaN       NaN     NaN
# ...          ...     ...      ...        ...     ...       ...     ...
# 2825    효성티앤씨(주)  298020  2018/12        NaN     NaN       NaN     NaN
# 2826    효성티앤씨(주)  298020  2019/12     158.22  338.18   21569.0  453.10
# 2827    효성티앤씨(주)  298020  2020/12     -17.45   46.96   31698.0  294.79
# 2828    효성티앤씨(주)  298020  2021/12     434.08  463.14  178503.0  156.66
# 2829    효성티앤씨(주)  298020  2022/12     -91.32  -98.50    2686.0  185.04
#
#       매출액정상영업이익률  매출액증가율  1주당 CASH FLOW     1주당순자산      PER    PBR     PCR
# ...

# %%
kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830 entries, 0 to 2829
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   회사명            2830 non-null   object
#  1   거래소코드          2830 non-null   int64
#  2   회계년도           2830 non-null   object
#  3   정상영업이익증가율      2433 non-null   float64
#  4   순이익증가율         2433 non-null   float64
#  5   1주당순이익         2433 non-null   float64
#  6   부채비율           2433 non-null   float64
#  7   매출액정상영업이익률     2433 non-null   float64
#  8   매출액증가율         2433 non-null   float64
#  9   1주당 CASH FLOW  2433 non-null   float64
#  10  1주당순자산         2433 non-null   float64
#  11  PER            2433 non-null   float64
#  12  PBR            2433 non-null   float64
#  13  PCR            2433 non-null   float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 309.7+ KB

# %%
#kospi['거래소코드'].unique()
kospi['거래소코드'] = kospi['거래소코드'].astype(str).str.zfill(6)

# %%
kospi['거래소코드'].unique()
# Out:
# array(['138930', '000990', '175330', '105560', '035250', '006280',
#        '005250', '004370', '047040', '003090', '069620', '003490',
#        '192080', '026960', '000150', '138040', '003850', '282330',
#        '068270', '004170', '031430', '055550', '090430', '002790',
#        '012750', '383220', '036570', '006260', '001120', '003550',
#        '051900', '373220', '032640', '051910', '111770', '000670',
#        '007310', '271560', '001800', '316140', '000100', '139480',
#        '030000', '185750', '013890', '078930', '007070', '035720',
#        '323410', '377300', '002380', '030200', '033780', '259960',
#        '047050', '003670', '103140', '086790', '039130', '352820',
#        '009240', '020000', '014680', '180640', '000880', '010620',
#        '069960', '005440', '057050', '008770', '241590', '004800',
#        '093370', '081660', '005830', '267250', '016380', '011070',
#        '010120', '096770', '010130', '114090', '011780', '073240',
# ...

# %%
kospi['회계년도'].unique()
# Out:
# array(['2011/12', '2012/12', '2013/12', '2014/12', '2015/12', '2016/12',
#        '2017/12', '2018/12', '2019/12', '2020/12', '2021/12', '2022/12',
#        '2007/12', '2008/12', '2009/12', '2010/12', '2007/03', '2008/03',
#        '2009/03', '2010/03', '2011/03', '2012/03', '2013/03'],
#       dtype=object)

# %%
# kospi = kospi[kospi['회계년도'].str.contains(r'\d{4}/12')]

# %%
# kospi.to_csv('kospi_사업_결측치존재.csv', encoding='utf-8-sig')

# %%
# kospii.to_csv('kospi_반기.csv', encoding='utf-8-sig')

# %%
kospi
# Out:
#              회사명   거래소코드     회계년도  정상영업이익증가율  순이익증가율    1주당순이익    부채비율
# 0     (주)BNK금융지주  138930  2011/12        NaN     NaN       NaN     NaN  \
# 1     (주)BNK금융지주  138930  2012/12        NaN     NaN       NaN     NaN
# 2     (주)BNK금융지주  138930  2013/12        NaN     NaN       NaN     NaN
# 3     (주)BNK금융지주  138930  2014/12        NaN     NaN       NaN     NaN
# 4     (주)BNK금융지주  138930  2015/12        NaN     NaN       NaN     NaN
# ...          ...     ...      ...        ...     ...       ...     ...
# 2825    효성티앤씨(주)  298020  2018/12        NaN     NaN       NaN     NaN
# 2826    효성티앤씨(주)  298020  2019/12     158.22  338.18   21569.0  453.10
# 2827    효성티앤씨(주)  298020  2020/12     -17.45   46.96   31698.0  294.79
# 2828    효성티앤씨(주)  298020  2021/12     434.08  463.14  178503.0  156.66
# 2829    효성티앤씨(주)  298020  2022/12     -91.32  -98.50    2686.0  185.04
#
#       매출액정상영업이익률  매출액증가율  1주당 CASH FLOW     1주당순자산      PER    PBR     PCR
# ...

# %%
kospi = pd.merge(kospi, k2[['거래소코드', '회계년도', '종가']], on=['거래소코드', '회계년도'], how='left')

# %%
kospi.isnull()
# Out:
#         회사명  거래소코드   회계년도  정상영업이익증가율  순이익증가율  1주당순이익   부채비율  매출액정상영업이익률
# 0     False  False  False       True    True    True   True        True  \
# 1     False  False  False       True    True    True   True        True
# 2     False  False  False       True    True    True   True        True
# 3     False  False  False       True    True    True   True        True
# 4     False  False  False       True    True    True   True        True
# ...     ...    ...    ...        ...     ...     ...    ...         ...
# 2825  False  False  False       True    True    True   True        True
# 2826  False  False  False      False   False   False  False       False
# 2827  False  False  False      False   False   False  False       False
# 2828  False  False  False      False   False   False  False       False
# 2829  False  False  False      False   False   False  False       False
#
#       매출액증가율  1주당 CASH FLOW  1주당순자산    PER    PBR    PCR     종가    per    pbr
# ...

# %%
kospi['per'] = kospi["종가"]/ kospi["1주당순이익"]
kospi['pbr'] = kospi["종가"]/ kospi["1주당순자산"]
kospi['pcr'] = kospi["종가"]/ kospi["1주당 CASH FLOW"]

# %%
kospi.isna().sum()
# Out:
# 회사명                0
# 거래소코드              0
# 회계년도               0
# 정상영업이익증가율        397
# 순이익증가율           397
# 1주당순이익           397
# 부채비율             397
# 매출액정상영업이익률       397
# 매출액증가율           397
# 1주당 CASH FLOW    397
# 1주당순자산           397
# PER              397
# PBR              397
# PCR              397
# 종가               689
# per              882
# pbr              882
# pcr              882
# dtype: int64
