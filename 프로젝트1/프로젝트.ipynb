# %%
import pandas as pd
import numpy as np

# %%
kospi_1 = pd.read_csv("./거시경제변수데이터/코스피200_사업보고서연결.csv", encoding = "euc-kr")
kospi_2 = pd.read_csv("./거시경제변수데이터/코스피200_사업보고서개별.csv", encoding = "euc-kr")
kospi_3 = pd.read_csv("./거시경제변수데이터/코스피200_반기보고서연결.csv", encoding = "euc-kr")
kospi_4 = pd.read_csv("./거시경제변수데이터/코스피200_반기보고서개별.csv", encoding = "euc-kr")

# %%
kospi_1.columns = ['회사명', '거래소코드', '회계년도', '정상영업이익증가율', '순이익증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '매출액증가율', 'PER(최고)(IFRS)', 'PER(최저)(IFRS)', 'PBR(최고)(IFRS)', 'PBR(최저)(IFRS)', 'PCR(최고)(IFRS)', 'PCR(최저)(IFRS)']
kospi_3.columns = ['회사명', '거래소코드', '회계년도', '정상영업이익증가율', '순이익증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '매출액증가율', 'PER(최고)(IFRS)', 'PER(최저)(IFRS)', 'PBR(최고)(IFRS)', 'PBR(최저)(IFRS)', 'PCR(최고)(IFRS)', 'PCR(최저)(IFRS)']

# %%
kospi_2.columns = ['회사명', '거래소코드', '회계년도', '정상영업이익증가율', '순이익증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '매출액증가율']
kospi_4.columns = ['회사명', '거래소코드', '회계년도', '정상영업이익증가율', '순이익증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '매출액증가율']

# %%
kospi_c = kospi_1[['회사명', '거래소코드', '회계년도', '정상영업이익증가율', '순이익증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '매출액증가율']]
kospi_d = kospi_3[['회사명', '거래소코드', '회계년도', '정상영업이익증가율', '순이익증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '매출액증가율']]

# %%
kospi = kospi_c.fillna(kospi_2)
kospii = kospi_d.fillna(kospi_4)

# %%
kospi_ = kospi_1[['PER(최고)(IFRS)', 'PER(최저)(IFRS)', 'PBR(최고)(IFRS)', 'PBR(최저)(IFRS)', 'PCR(최고)(IFRS)', 'PCR(최저)(IFRS)']]
kospi__ = kospi_3[['PER(최고)(IFRS)', 'PER(최저)(IFRS)', 'PBR(최고)(IFRS)', 'PBR(최저)(IFRS)', 'PCR(최고)(IFRS)', 'PCR(최저)(IFRS)']]

# %%
kospi.isna().sum()
# Out:
# 회사명             0
# 거래소코드           0
# 회계년도            0
# 정상영업이익증가율     397
# 순이익증가율        397
# 1주당순이익        397
# 부채비율          397
# 매출액정상영업이익률    397
# 매출액증가율        397
# dtype: int64

# %%
kospii.isna().sum()
# Out:
# 회사명             0
# 거래소코드           0
# 회계년도            0
# 정상영업이익증가율     349
# 순이익증가율        349
# 1주당순이익        349
# 부채비율          349
# 매출액정상영업이익률    349
# 매출액증가율        349
# dtype: int64

# %%
kospi = pd.concat([kospi, kospi_], axis=1)
kospii = pd.concat([kospii, kospi__], axis=1)

# %%
kospi.isna().sum()
# Out:
# 회사명                0
# 거래소코드              0
# 회계년도               0
# 정상영업이익증가율        397
# 순이익증가율           397
# 1주당순이익           397
# 부채비율             397
# 매출액정상영업이익률       397
# 매출액증가율           397
# PER(최고)(IFRS)    397
# PER(최저)(IFRS)    397
# PBR(최고)(IFRS)    397
# PBR(최저)(IFRS)    397
# PCR(최고)(IFRS)    397
# PCR(최저)(IFRS)    397
# dtype: int64

# %%
kospii.isna().sum()
# Out:
# 회사명                 0
# 거래소코드               0
# 회계년도                0
# 정상영업이익증가율         349
# 순이익증가율            349
# 1주당순이익            349
# 부채비율              349
# 매출액정상영업이익률        349
# 매출액증가율            349
# PER(최고)(IFRS)     349
# PER(최저)(IFRS)     349
# PBR(최고)(IFRS)    2639
# PBR(최저)(IFRS)    2639
# PCR(최고)(IFRS)     349
# PCR(최저)(IFRS)     349
# dtype: int64

# %%
kospii
# Out:
#              회사명   거래소코드     회계년도  정상영업이익증가율   순이익증가율   1주당순이익    부채비율
# 0     (주)BNK금융지주  138930  2011/06        NaN      NaN      NaN     NaN  \
# 1     (주)BNK금융지주  138930  2012/06        NaN      NaN      NaN     NaN
# 2     (주)BNK금융지주  138930  2013/06        NaN      NaN      NaN     NaN
# 3     (주)BNK금융지주  138930  2014/06        NaN      NaN      NaN     NaN
# 4     (주)BNK금융지주  138930  2015/06        NaN      NaN      NaN     NaN
# ...          ...     ...      ...        ...      ...      ...     ...
# 2634    효성티앤씨(주)  298020  2018/06        NaN      NaN      NaN     NaN
# 2635    효성티앤씨(주)  298020  2019/06     551.38     0.00  14680.0  477.87
# 2636    효성티앤씨(주)  298020  2020/06     -52.21   -89.17   1590.0  427.40
# 2637    효성티앤씨(주)  298020  2021/06     801.67  5379.39  87118.0  201.77
# 2638    효성티앤씨(주)  298020  2022/06     -56.21   -74.84  21917.0  210.84
#
#       매출액정상영업이익률  매출액증가율  PER(최고)(IFRS)  PER(최저)(IFRS)  PBR(최고)(IFRS)
# ...

# %%
kospi['회계년도'].unique()
# Out:
# array(['2011/12', '2012/12', '2013/12', '2014/12', '2015/12', '2016/12',
#        '2017/12', '2018/12', '2019/12', '2020/12', '2021/12', '2022/12',
#        '2007/12', '2008/12', '2009/12', '2010/12', '2007/03', '2008/03',
#        '2009/03', '2010/03', '2011/03', '2012/03', '2013/03'],
#       dtype=object)

# %%
kospii['회계년도'].unique()
# Out:
# array(['2011/06', '2012/06', '2013/06', '2014/06', '2015/06', '2016/06',
#        '2017/06', '2018/06', '2019/06', '2020/06', '2021/06', '2022/06',
#        '2007/06', '2008/06', '2009/06', '2010/06', '2007/09', '2008/09',
#        '2009/09', '2010/09', '2011/09', '2012/09', '2013/09'],
#       dtype=object)

# %%
kospi = kospi.reset_index(drop=True)

# %%
kospi.isna().sum()
# Out:
# 회사명                0
# 거래소코드              0
# 회계년도               0
# 정상영업이익증가율        397
# 순이익증가율           397
# 1주당순이익           397
# 부채비율             397
# 매출액정상영업이익률       397
# 매출액증가율           397
# PER(최고)(IFRS)    397
# PER(최저)(IFRS)    397
# PBR(최고)(IFRS)    397
# PBR(최저)(IFRS)    397
# PCR(최고)(IFRS)    397
# PCR(최저)(IFRS)    397
# dtype: int64

# %%
len(kospi["회사명"].unique())
# Out:
# 200

# %%
kospi["PER"] = (kospi["PER(최고)(IFRS)"] + kospi["PER(최저)(IFRS)"])/2
kospi["PBR"] = (kospi["PBR(최고)(IFRS)"] + kospi["PBR(최저)(IFRS)"])/2
kospi["PCR"] = (kospi["PCR(최고)(IFRS)"] + kospi["PCR(최저)(IFRS)"])/2

# %%
kospii["PER"] = (kospii["PER(최고)(IFRS)"] + kospii["PER(최저)(IFRS)"])/2
kospii["PBR"] = (kospii["PBR(최고)(IFRS)"] + kospii["PBR(최저)(IFRS)"])/2
kospii["PCR"] = (kospii["PCR(최고)(IFRS)"] + kospii["PCR(최저)(IFRS)"])/2

# %%
kospi.drop(["PER(최고)(IFRS)", "PER(최저)(IFRS)", "PBR(최고)(IFRS)", "PBR(최저)(IFRS)", "PCR(최고)(IFRS)", "PCR(최저)(IFRS)"], axis=1, inplace=True)
kospii.drop(["PER(최고)(IFRS)", "PER(최저)(IFRS)", "PBR(최고)(IFRS)", "PBR(최저)(IFRS)", "PCR(최고)(IFRS)", "PCR(최저)(IFRS)"], axis=1, inplace=True)

# %%
kospi
# Out:
#              회사명   거래소코드     회계년도  정상영업이익증가율  순이익증가율    1주당순이익    부채비율
# 0     (주)BNK금융지주  138930  2011/12        NaN     NaN       NaN     NaN  \
# 1     (주)BNK금융지주  138930  2012/12        NaN     NaN       NaN     NaN
# 2     (주)BNK금융지주  138930  2013/12        NaN     NaN       NaN     NaN
# 3     (주)BNK금융지주  138930  2014/12        NaN     NaN       NaN     NaN
# 4     (주)BNK금융지주  138930  2015/12        NaN     NaN       NaN     NaN
# ...          ...     ...      ...        ...     ...       ...     ...
# 2825    효성티앤씨(주)  298020  2018/12        NaN     NaN       NaN     NaN
# 2826    효성티앤씨(주)  298020  2019/12     158.22  338.18   21569.0  453.10
# 2827    효성티앤씨(주)  298020  2020/12     -17.45   46.96   31698.0  294.79
# 2828    효성티앤씨(주)  298020  2021/12     434.08  463.14  178503.0  156.66
# 2829    효성티앤씨(주)  298020  2022/12     -91.32  -98.50    2686.0  185.04
#
#       매출액정상영업이익률  매출액증가율      PER    PBR     PCR
# 0            NaN     NaN      NaN    NaN     NaN
# ...

# %%
kospii
# Out:
#              회사명   거래소코드     회계년도  정상영업이익증가율   순이익증가율   1주당순이익    부채비율
# 0     (주)BNK금융지주  138930  2011/06        NaN      NaN      NaN     NaN  \
# 1     (주)BNK금융지주  138930  2012/06        NaN      NaN      NaN     NaN
# 2     (주)BNK금융지주  138930  2013/06        NaN      NaN      NaN     NaN
# 3     (주)BNK금융지주  138930  2014/06        NaN      NaN      NaN     NaN
# 4     (주)BNK금융지주  138930  2015/06        NaN      NaN      NaN     NaN
# ...          ...     ...      ...        ...      ...      ...     ...
# 2634    효성티앤씨(주)  298020  2018/06        NaN      NaN      NaN     NaN
# 2635    효성티앤씨(주)  298020  2019/06     551.38     0.00  14680.0  477.87
# 2636    효성티앤씨(주)  298020  2020/06     -52.21   -89.17   1590.0  427.40
# 2637    효성티앤씨(주)  298020  2021/06     801.67  5379.39  87118.0  201.77
# 2638    효성티앤씨(주)  298020  2022/06     -56.21   -74.84  21917.0  210.84
#
#       매출액정상영업이익률  매출액증가율     PER  PBR     PCR
# 0            NaN     NaN     NaN  NaN     NaN
# ...

# %%
kospi['회계년도'].unique()
# Out:
# array(['2011/12', '2012/12', '2013/12', '2014/12', '2015/12', '2016/12',
#        '2017/12', '2018/12', '2019/12', '2020/12', '2021/12', '2022/12',
#        '2007/12', '2008/12', '2009/12', '2010/12', '2007/03', '2008/03',
#        '2009/03', '2010/03', '2011/03', '2012/03', '2013/03'],
#       dtype=object)

# %%
kospii['회계년도'].unique()
# Out:
# array(['2011/06', '2012/06', '2013/06', '2014/06', '2015/06', '2016/06',
#        '2017/06', '2018/06', '2019/06', '2020/06', '2021/06', '2022/06',
#        '2007/06', '2008/06', '2009/06', '2010/06', '2007/09', '2008/09',
#        '2009/09', '2010/09', '2011/09', '2012/09', '2013/09'],
#       dtype=object)

# %%
kospi[kospi['회계년도'] == '2022/11']
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 정상영업이익증가율, 순이익증가율, 1주당순이익, 부채비율, 매출액정상영업이익률, 매출액증가율, PER, PBR, PCR]
# Index: []

# %%
kospi = kospi[kospi['회계년도'].str.contains(r'\d{4}/12')]

# %%
kospii = kospii[kospii['회계년도'].str.contains(r'\d{4}/06')]

# %%
kospi.reset_index(drop=True)
# Out:
#              회사명   거래소코드     회계년도  정상영업이익증가율  순이익증가율    1주당순이익    부채비율
# 0     (주)BNK금융지주  138930  2011/12        NaN     NaN       NaN     NaN  \
# 1     (주)BNK금융지주  138930  2012/12        NaN     NaN       NaN     NaN
# 2     (주)BNK금융지주  138930  2013/12        NaN     NaN       NaN     NaN
# 3     (주)BNK금융지주  138930  2014/12        NaN     NaN       NaN     NaN
# 4     (주)BNK금융지주  138930  2015/12        NaN     NaN       NaN     NaN
# ...          ...     ...      ...        ...     ...       ...     ...
# 2731    효성티앤씨(주)  298020  2018/12        NaN     NaN       NaN     NaN
# 2732    효성티앤씨(주)  298020  2019/12     158.22  338.18   21569.0  453.10
# 2733    효성티앤씨(주)  298020  2020/12     -17.45   46.96   31698.0  294.79
# 2734    효성티앤씨(주)  298020  2021/12     434.08  463.14  178503.0  156.66
# 2735    효성티앤씨(주)  298020  2022/12     -91.32  -98.50    2686.0  185.04
#
#       매출액정상영업이익률  매출액증가율      PER    PBR     PCR
# 0            NaN     NaN      NaN    NaN     NaN
# ...

# %%
kospii.reset_index(drop=True)
# Out:
#              회사명   거래소코드     회계년도  정상영업이익증가율   순이익증가율   1주당순이익    부채비율
# 0     (주)BNK금융지주  138930  2011/06        NaN      NaN      NaN     NaN  \
# 1     (주)BNK금융지주  138930  2012/06        NaN      NaN      NaN     NaN
# 2     (주)BNK금융지주  138930  2013/06        NaN      NaN      NaN     NaN
# 3     (주)BNK금융지주  138930  2014/06        NaN      NaN      NaN     NaN
# 4     (주)BNK금융지주  138930  2015/06        NaN      NaN      NaN     NaN
# ...          ...     ...      ...        ...      ...      ...     ...
# 2542    효성티앤씨(주)  298020  2018/06        NaN      NaN      NaN     NaN
# 2543    효성티앤씨(주)  298020  2019/06     551.38     0.00  14680.0  477.87
# 2544    효성티앤씨(주)  298020  2020/06     -52.21   -89.17   1590.0  427.40
# 2545    효성티앤씨(주)  298020  2021/06     801.67  5379.39  87118.0  201.77
# 2546    효성티앤씨(주)  298020  2022/06     -56.21   -74.84  21917.0  210.84
#
#       매출액정상영업이익률  매출액증가율     PER  PBR     PCR
# 0            NaN     NaN     NaN  NaN     NaN
# ...

# %%
# kospi.to_csv('kospi_사업_결측치존재.csv', encoding='utf-8-sig')

# %%
# kospii.to_csv('kospi_반기.csv', encoding='utf-8-sig')
