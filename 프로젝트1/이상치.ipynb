# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./거시경제변수데이터/상대가치데이터.csv")

# %%
data
# Out:
#        Unnamed: 0        PER       PBR        PCR       PSR  배당수익률(%)
# 0      2007-03-01        NaN       NaN        NaN       NaN       NaN  \
# 1      2007-06-01        NaN       NaN        NaN       NaN       NaN
# 2      2007-09-01        NaN       NaN        NaN       NaN       NaN
# 3      2007-12-01        NaN       NaN        NaN       NaN       NaN
# 4      2008-03-01        NaN       NaN        NaN       NaN       NaN
# ...           ...        ...       ...        ...       ...       ...
# 11515  2021-12-01        NaN       NaN        NaN       NaN       NaN
# 11516  2022-03-01  20.680000  0.465833  17.695000  6.769167       NaN
# 11517  2022-06-01  18.243710  0.410968  15.609516  5.970968       NaN
# 11518  2022-09-01  15.346825  0.344921  13.131746  5.023016       NaN
# 11519  2022-12-01  14.060484  0.315484  12.030323  4.601290       NaN
#
#        정상영업이익증가율     순이익증가율     매출액증가율  1주당순이익      부채비율  매출액정상영업이익률    종목코드
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'PER', 'PBR', 'PCR', 'PSR', '배당수익률(%)', '정상영업이익증가율',
#        '순이익증가율', '매출액증가율', '1주당순이익', '부채비율', '매출액정상영업이익률', '종목코드'],
#       dtype='object')

# %%
data = data.fillna(0)

# %%
data[data['부채비율'] < 0]
# Out:
#        Unnamed: 0        PER        PBR        PCR        PSR  배당수익률(%)
# 1      2007-06-01   0.000000   0.000000   0.000000   0.000000  0.000000  \
# 2      2007-09-01   0.000000   0.000000   0.000000   0.000000  0.000000
# 3      2007-12-01   0.000000   0.000000   0.000000   0.000000  0.000000
# 5      2008-06-01   0.000000   0.000000   0.000000   0.000000  0.000000
# 6      2008-09-01   0.000000   0.000000   0.000000   0.000000  0.000000
# ...           ...        ...        ...        ...        ...       ...
# 11327  2022-12-01   0.000000   3.940161   0.000000  12.781935  0.000000
# 11389  2022-06-01  25.802581   4.526613  13.354677   0.634194  2.964032
# 11390  2022-09-01  19.290635   3.383810   9.984444   0.474444  3.918254
# 11453  2022-06-01  22.964839   9.665323  20.464677   4.890161  0.794194
# 11455  2022-12-01  24.109516  10.145806  21.484677   5.133710  0.755000
#
#        정상영업이익증가율    순이익증가율    매출액증가율   1주당순이익      부채비율  매출액정상영업이익률    종목코드
# ...

# %%
## 윈저라이징 전 박스플롯

import matplotlib.pyplot as plt

data_num = data[['PER', 'PBR', 'PCR', 'PSR', '배당수익률(%)', '정상영업이익증가율','순이익증가율', '매출액증가율', '1주당순이익', '부채비율', '매출액정상영업이익률']]
data_num_col = data[['PER', 'PBR', 'PCR', 'PSR', '배당수익률(%)', '정상영업이익증가율','순이익증가율', '매출액증가율', '1주당순이익', '부채비율', '매출액정상영업이익률']].columns

# 행과 열의 수 계산
n = len(data_num_col)
ncols = 4
nrows = n // ncols + (n % ncols > 0)

# 서브플롯 생성
fig, axes = plt.subplots(nrows, ncols, figsize=(15, nrows*5))

for i, var in enumerate(data_num_col):
    r, c = i // ncols, i % ncols
    ax = axes[r, c]
    data_num.boxplot(column=var, ax=ax)

# 빈 서브플롯 제거
if n % ncols > 0:
    for j in range(n % ncols, ncols):
        fig.delaxes(axes[nrows-1, j])

plt.tight_layout()  #  plt.tight_layout() 함수는 서브플롯 간의 간격을 적절하게 조절합니다.
plt.show()

# %%
data.columns'Unnamed: 0', '종목코드'
# Out:
#   Cell In[8], line 1
#     data.columns'Unnamed: 0', '종목코드'
#                 ^
# SyntaxError: invalid syntax

# %%
# 윈저라이징 전 qqplot

from scipy import stats

def qqplot(df,ncols,nrows):
    plt.rcParams['axes.unicode_minus'] = False
    plt.rcParams["font.family"] = 'Malgun Gothic'
   
    fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
    fig.set_size_inches((40, 20))

    for ax, i in zip(axs.ravel(), df):
            stats.probplot(df[i], dist=stats.norm, plot=ax)
            ax.set_title(str(i))

    plt.show()

qqplot(data[['PER', 'PBR', 'PCR', 'PSR', '배당수익률(%)', '정상영업이익증가율','순이익증가율', '매출액증가율', '1주당순이익', '부채비율', '매출액정상영업이익률']],4,3)
# Out:
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
data_num['PER']

q2 = np.percentile(data_num['PER'], 1)
q98 = np.percentile(data_num['PER'], 99)

outliers = data_num['PER'][(data_num['PER'] < q2) | (data_num['PER'] > q98)]

print("하위 2%:", q2)
print("상위 2%:", q98)
print("이상치 :", outliers)
# Out:
# 하위 2%: 0.0
# 상위 2%: 346.08855682539644
# 이상치 : 140        470.076230
# 141        492.364677
# 142        494.353016
# 143        610.776308
# 195        454.074032
#              ...
# 10619    38224.574921
# 10620    20059.350000
# 10744      439.084444
# 10746      446.720484
# 10747      449.967460
# Name: PER, Length: 116, dtype: float64

# %%
# # 윈저라이징 함수 만들기
# def windsorize(data, lower_percentile=0.01, upper_percentile=0.99):
#     if isinstance(data, pd.Series):
#         data = pd.DataFrame(data)
#     numeric_df = data.select_dtypes(include=np.number)
#     lower_bound = np.percentile(numeric_df, lower_percentile * 100)
#     upper_bound = np.percentile(numeric_df, upper_percentile * 100)
#     windsorized_data = np.where(numeric_df < lower_bound, lower_bound, numeric_df)
#     windsorized_data = np.where(windsorized_data > upper_bound, upper_bound, windsorized_data)
#     return windsorized_data

# %%
# for i in range(0, 7, 1):
#     data_num[data_num.columns[i]] = windsorize(data_num[data_num.columns[i]])

# %%
# data_num = data[['PER', 'PBR', 'PCR', 'PSR', '배당수익률(%)', '정상영업이익증가율','순이익증가율', '매출액증가율', '1주당순이익', '부채비율', '매출액정상영업이익률']]
# q_upper = data_num['PER'].quantile(0.99)
# q_lower = data_num['PER'].quantile(0.01)

# data_num.loc[(data_num['PER'] > q_upper) | (data_num['PER'] < q_lower), 'PER'] = np.nan

# %%
data['PSR']

q2 = np.percentile(data['PSR'], 1)
q98 = np.percentile(data['PSR'], 99)

outliers = data['PSR'][(data['PSR'] < q2) | (data['PSR'] > q98)]

print("하위 2%:", q2)
print("상위 2%:", q98)
print("이상치 :", outliers)
# Out:
# 하위 2%: 0.0
# 상위 2%: 17.537888471707962
# 이상치 : 344      51.080984
# 345      55.114032
# 346      69.586290
# 347      67.886452
# 3280     23.520333
#            ...
# 11131    21.253651
# 11196    40.675750
# 11323    65.312143
# 11324    48.506610
# 11325    25.545968
# Name: PSR, Length: 116, dtype: float64

# %%
import numpy as np

columns = ['PER', 'PBR', 'PCR', 'PSR', '배당수익률(%)', '정상영업이익증가율', '순이익증가율', '매출액증가율', '1주당순이익', '부채비율', '매출액정상영업이익률']

for column in columns:
    q_upper = data_num[column].quantile(0.995)
    q_lower = data_num[column].quantile(0.005)
    data_num.loc[(data_num[column] > q_upper) | (data_num[column] < q_lower), column] = np.nan
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_21173/2740586226.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_num.loc[(data_num[column] > q_upper) | (data_num[column] < q_lower), column] = np.nan
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_21173/2740586226.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_num.loc[(data_num[column] > q_upper) | (data_num[column] < q_lower), column] = np.nan
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_21173/2740586226.py:8: SettingWithCopyWarning:
# ...

# %%
data_num.isnull().sum()
# Out:
# PER            58
# PBR            58
# PCR            58
# PSR            58
# 배당수익률(%)       58
# 정상영업이익증가율     116
# 순이익증가율        116
# 매출액증가율        116
# 1주당순이익        116
# 부채비율          116
# 매출액정상영업이익률    116
# dtype: int64

# %%
data = pd.concat([data[['Unnamed: 0', '종목코드']], data_num], axis=1)

# %%
data
# Out:
#        Unnamed: 0    종목코드        PER       PBR        PCR       PSR  배당수익률(%)
# 0      2007-03-01      80   0.000000  0.000000   0.000000  0.000000       0.0  \
# 1      2007-06-01      80   0.000000  0.000000   0.000000  0.000000       0.0
# 2      2007-09-01      80   0.000000  0.000000   0.000000  0.000000       0.0
# 3      2007-12-01      80   0.000000  0.000000   0.000000  0.000000       0.0
# 4      2008-03-01      80   0.000000  0.000000   0.000000  0.000000       0.0
# ...           ...     ...        ...       ...        ...       ...       ...
# 11515  2021-12-01  402340   0.000000  0.000000   0.000000  0.000000       0.0
# 11516  2022-03-01  402340  20.680000  0.465833  17.695000  6.769167       0.0
# 11517  2022-06-01  402340  18.243710  0.410968  15.609516  5.970968       0.0
# 11518  2022-09-01  402340  15.346825  0.344921  13.131746  5.023016       0.0
# 11519  2022-12-01  402340  14.060484  0.315484  12.030323  4.601290       0.0
#
# ...

# %%
data.to_csv('Featur.csv', encoding= 'utf-8-sig')

# %%
import platform

if platform.system() == 'Darwin':
    plt.rc('font', family = 'AppleGothic')
else:
    plt.rc('font', family = 'Malgun Gothic')

# %%
## 윈저라이징 후 박스플롯

import matplotlib.pyplot as plt

# 행과 열의 수 계산
n = len(data_num.columns)
ncols = 4
nrows = n // ncols + (n % ncols > 0)

# 서브플롯 생성
fig, axes = plt.subplots(nrows, ncols, figsize=(15, nrows*5))

for i, var in enumerate(data_num.columns):
    r, c = i // ncols, i % ncols
    ax = axes[r, c]
    data_num.boxplot(column=var, ax=ax)

# 빈 서브플롯 제거
if n % ncols > 0:
    for j in range(n % ncols, ncols):
        fig.delaxes(axes[nrows-1, j])

plt.tight_layout()  #  plt.tight_layout() 함수는 서브플롯 간의 간격을 적절하게 조절합니다.
plt.show()

# %%
# data_num = data_num.replace(0, np.nan).dropna()

# %%
# 윈저라이징 후 qqplot

from scipy import stats

def qqplot(df,ncols,nrows):
    plt.rcParams['axes.unicode_minus'] = False
    plt.rcParams["font.family"] = 'Malgun Gothic'
   
    fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
    fig.set_size_inches((40, 20))

    for ax, i in zip(axs.ravel(), df):
            stats.probplot(df[i], dist=stats.norm, plot=ax)
            ax.set_title(str(i))

    plt.show()

qqplot(data_num,4,3)
# Out:
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
data
# Out:
#        Unnamed: 0        PER       PBR        PCR       PSR  배당수익률(%)
# 0      2007-03-01   0.000000  0.000000   0.000000  0.000000       0.0  \
# 1      2007-06-01   0.000000  0.000000   0.000000  0.000000       0.0
# 2      2007-09-01   0.000000  0.000000   0.000000  0.000000       0.0
# 3      2007-12-01   0.000000  0.000000   0.000000  0.000000       0.0
# 4      2008-03-01   0.000000  0.000000   0.000000  0.000000       0.0
# ...           ...        ...       ...        ...       ...       ...
# 11515  2021-12-01   0.000000  0.000000   0.000000  0.000000       0.0
# 11516  2022-03-01  20.680000  0.465833  17.695000  6.769167       0.0
# 11517  2022-06-01  18.243710  0.410968  15.609516  5.970968       0.0
# 11518  2022-09-01  15.346825  0.344921  13.131746  5.023016       0.0
# 11519  2022-12-01  14.060484  0.315484  12.030323  4.601290       0.0
#
#        정상영업이익증가율     순이익증가율     매출액증가율  1주당순이익      부채비율  매출액정상영업이익률    종목코드
# ...

# %%
data_num
# Out:
#              PER       PBR        PCR       PSR  배당수익률(%)  정상영업이익증가율
# 0       0.000000  0.000000   0.000000  0.000000       0.0   1.757224  \
# 1       0.000000  0.000000   0.000000  0.000000       0.0  -1.757224
# 2       0.000000  0.000000   0.000000  0.000000       0.0   0.120883
# 3       0.000000  0.000000   0.000000  0.000000       0.0  -0.120883
# 4       0.000000  0.000000   0.000000  0.000000       0.0   0.052330
# ...          ...       ...        ...       ...       ...        ...
# 11515   0.000000  0.000000   0.000000  0.000000       0.0   0.000000
# 11516  20.680000  0.465833  17.695000  6.769167       0.0  -9.519843
# 11517  18.243710  0.410968  15.609516  5.970968       0.0   0.000000
# 11518  15.346825  0.344921  13.131746  5.023016       0.0   0.000000
# 11519  14.060484  0.315484  12.030323  4.601290       0.0   0.000000
#
#           순이익증가율    매출액증가율  1주당순이익      부채비율  매출액정상영업이익률
# 0       2.475036       NaN     0.0  7.316072    0.197916
# ...
