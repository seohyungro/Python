# %%
import requests
from urllib import parse
import xmltodict
import pandas as pd
import pprint

# %%
## openapi를 이용하여 서버와의 통신하여 데이터를 가져오는 작업

## 어느 서버에서 데이터를 가져와야되는지 주소를 입력
url = "http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson"

## 공공데이터포털에서 주소와 함께 request parameter
## 서비스키
service_key = "dtbWOdJ%2FCz5HE0DGLU%2BCRPe7pOW0NIQBUcGEqsHZaTRiYCI%2F5%2BzugwzQjcvuId7NPdg6rUiW%2Bft3fm7yqyD4pw%3D%3D"
## 페이지번호
## 페이지당 데이터의 개수
## 시작 시간
## 종료 시간
param = {
    'serviceKey' : parse.unquote(service_key), 
    'pageNo' : '1', 
    'numOfRows' : '5000', 
    'startCreateDt' : '20220101', 
    'endCreateDt' : '20230407'
}


## 여기부터 통신을 시작
response = requests.get(url, params = param)
## response의 데이터의 형태는 xml

## xml데이터를 딕셔너리 형태의 데이터로 변환
result = xmltodict.parse(response.content)

print(result)
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}, 'body': {'items': {'item': [{'createDt': '2023-04-07 00:16:52.0', 'deathCnt': '34318', 'decideCnt': '30894559', 'seq': '1218', 'stateDt': '20230407', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-04-05 02:12:00.0', 'deathCnt': '34296', 'decideCnt': '30871740', 'seq': '1216', 'stateDt': '20230405', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-04-04 05:10:20.0', 'deathCnt': '34289', 'decideCnt': '30857275', 'seq': '1215', 'stateDt': '20230404', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-04-03 00:00:13.0', 'deathCnt': '34281', 'decideCnt': '30843900', 'seq': '1214', 'stateDt': '20230403', 'stateTime': '00:00', 'updateDt': '2023-04-03 04:18:40.0'}, {'createDt': '2023-04-02 22:59:44.0', 'deathCnt': '34274', 'decideCnt': '30839551', 'seq': '1213', 'stateDt': '20230402', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-04-01 00:03:42.0', 'deathCnt': '34270', 'decideCnt': '30829827', 'seq': '1212', 'stateDt': '20230401', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-03-31 02:03:57.0', 'deathCnt': '34265', 'decideCnt': '30819304', 'seq': '1211', 'stateDt': '20230331', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:47:46.0'}, {'createDt': '2023-03-30 00:35:56.0', 'deathCnt': '34255', 'decideCnt': '30808936', 'seq': '1210', 'stateDt': '20230330', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:47:53.0'}, {'createDt': '2023-03-29 00:43:53.0', 'deathCnt': '34245', 'decideCnt': '30797904', 'seq': '1209', 'stateDt': '20230329', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:01.0'}, {'createDt': '2023-03-28 02:58:50.0', 'deathCnt': '34231', 'decideCnt': '30784777', 'seq': '1208', 'stateDt': '20230328', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:15.0'}, {'createDt': '2023-03-27 00:01:50.0', 'deathCnt': '34223', 'decideCnt': '30772653', 'seq': '1207', 'stateDt': '20230327', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:26.0'}, {'createDt': '2023-03-26 22:25:52.0', 'deathCnt': '34220', 'decideCnt': '30768453', 'seq': '1206', 'stateDt': '20230326', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:33.0'}, {'createDt': '2023-03-25 00:22:01.0', 'deathCnt': '34217', 'decideCnt': '30759099', 'seq': '1205', 'stateDt': '20230325', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:45.0'}, {'createDt': '2023-03-24 05:46:03.0', 'deathCnt': '34211', 'decideCnt': '30748653', 'seq': '1204', 'stateDt': '20230324', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:53:28.0'}, {'createDt': '2023-03-23 01:46:31.0', 'deathCnt': '34201', 'decideCnt': '30739164', 'seq': '1203', 'stateDt': '20230323', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:25:41.0'}, {'createDt': '2023-03-22 00:01:22.0', 'deathCnt': '34187', 'decideCnt': '30727767', 'seq': '1202', 'stateDt': '20230322', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:26:13.0'}, {'createDt': '2023-03-21 00:47:09.0', 'deathCnt': '34178', 'decideCnt': '30714691', 'seq': '1201', 'stateDt': '20230321', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:26:31.0'}, {'createDt': '2023-03-20 02:11:21.0', 'deathCnt': '34171', 'decideCnt': '30702678', 'seq': '1200', 'stateDt': '20230320', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:27:26.0'}, {'createDt': '2023-03-18 00:03:26.0', 'deathCnt': '34159', 'decideCnt': '30689952', 'seq': '1198', 'stateDt': '20230318', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:27:50.0'}, {'createDt': '2023-03-17 02:04:30.0', 'deathCnt': '34155', 'decideCnt': '30680964', 'seq': '1197', 'stateDt': '20230317', 'stateTime': '00:00', 'updateDt': '2023-03-17 23:13:39.0'}, {'createDt': '2023-03-15 05:29:17.0', 'deathCnt': '34131', 'decideCnt': '30661967', 'seq': '1195', 'stateDt': '20230315', 'stateTime': '00:00', 'updateDt': '2023-03-17 23:13:59.0'}, {'createDt': '2023-03-14 00:01:36.0', 'deathCnt': '34121', 'decideCnt': '30650069', 'seq': '1194', 'stateDt': '20230314', 'stateTime': '00:00', 'updateDt': ' ...

# %%
rows = result["response"]["body"]["items"]["item"]
print(rows)
# Out:
# [{'createDt': '2023-04-07 00:16:52.0', 'deathCnt': '34318', 'decideCnt': '30894559', 'seq': '1218', 'stateDt': '20230407', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-04-05 02:12:00.0', 'deathCnt': '34296', 'decideCnt': '30871740', 'seq': '1216', 'stateDt': '20230405', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-04-04 05:10:20.0', 'deathCnt': '34289', 'decideCnt': '30857275', 'seq': '1215', 'stateDt': '20230404', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-04-03 00:00:13.0', 'deathCnt': '34281', 'decideCnt': '30843900', 'seq': '1214', 'stateDt': '20230403', 'stateTime': '00:00', 'updateDt': '2023-04-03 04:18:40.0'}, {'createDt': '2023-04-02 22:59:44.0', 'deathCnt': '34274', 'decideCnt': '30839551', 'seq': '1213', 'stateDt': '20230402', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-04-01 00:03:42.0', 'deathCnt': '34270', 'decideCnt': '30829827', 'seq': '1212', 'stateDt': '20230401', 'stateTime': '00:00', 'updateDt': 'null'}, {'createDt': '2023-03-31 02:03:57.0', 'deathCnt': '34265', 'decideCnt': '30819304', 'seq': '1211', 'stateDt': '20230331', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:47:46.0'}, {'createDt': '2023-03-30 00:35:56.0', 'deathCnt': '34255', 'decideCnt': '30808936', 'seq': '1210', 'stateDt': '20230330', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:47:53.0'}, {'createDt': '2023-03-29 00:43:53.0', 'deathCnt': '34245', 'decideCnt': '30797904', 'seq': '1209', 'stateDt': '20230329', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:01.0'}, {'createDt': '2023-03-28 02:58:50.0', 'deathCnt': '34231', 'decideCnt': '30784777', 'seq': '1208', 'stateDt': '20230328', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:15.0'}, {'createDt': '2023-03-27 00:01:50.0', 'deathCnt': '34223', 'decideCnt': '30772653', 'seq': '1207', 'stateDt': '20230327', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:26.0'}, {'createDt': '2023-03-26 22:25:52.0', 'deathCnt': '34220', 'decideCnt': '30768453', 'seq': '1206', 'stateDt': '20230326', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:33.0'}, {'createDt': '2023-03-25 00:22:01.0', 'deathCnt': '34217', 'decideCnt': '30759099', 'seq': '1205', 'stateDt': '20230325', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:48:45.0'}, {'createDt': '2023-03-24 05:46:03.0', 'deathCnt': '34211', 'decideCnt': '30748653', 'seq': '1204', 'stateDt': '20230324', 'stateTime': '00:00', 'updateDt': '2023-03-31 21:53:28.0'}, {'createDt': '2023-03-23 01:46:31.0', 'deathCnt': '34201', 'decideCnt': '30739164', 'seq': '1203', 'stateDt': '20230323', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:25:41.0'}, {'createDt': '2023-03-22 00:01:22.0', 'deathCnt': '34187', 'decideCnt': '30727767', 'seq': '1202', 'stateDt': '20230322', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:26:13.0'}, {'createDt': '2023-03-21 00:47:09.0', 'deathCnt': '34178', 'decideCnt': '30714691', 'seq': '1201', 'stateDt': '20230321', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:26:31.0'}, {'createDt': '2023-03-20 02:11:21.0', 'deathCnt': '34171', 'decideCnt': '30702678', 'seq': '1200', 'stateDt': '20230320', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:27:26.0'}, {'createDt': '2023-03-18 00:03:26.0', 'deathCnt': '34159', 'decideCnt': '30689952', 'seq': '1198', 'stateDt': '20230318', 'stateTime': '00:00', 'updateDt': '2023-03-25 00:27:50.0'}, {'createDt': '2023-03-17 02:04:30.0', 'deathCnt': '34155', 'decideCnt': '30680964', 'seq': '1197', 'stateDt': '20230317', 'stateTime': '00:00', 'updateDt': '2023-03-17 23:13:39.0'}, {'createDt': '2023-03-15 05:29:17.0', 'deathCnt': '34131', 'decideCnt': '30661967', 'seq': '1195', 'stateDt': '20230315', 'stateTime': '00:00', 'updateDt': '2023-03-17 23:13:59.0'}, {'createDt': '2023-03-14 00:01:36.0', 'deathCnt': '34121', 'decideCnt': '30650069', 'seq': '1194', 'stateDt': '20230314', 'stateTime': '00:00', 'updateDt': '2023-03-17 23:14:11.0'}, {'createDt': '2023-03-13 00:40:54.0', 'deathCnt': '34115', 'decideCnt': '3063867 ...

# %%
corona_df = pd.DataFrame(rows)
corona_df
# Out:
#                     createDt deathCnt decideCnt   seq   stateDt stateTime
# 0      2023-04-07 00:16:52.0    34318  30894559  1218  20230407     00:00  \
# 1      2023-04-05 02:12:00.0    34296  30871740  1216  20230405     00:00
# 2      2023-04-04 05:10:20.0    34289  30857275  1215  20230404     00:00
# 3      2023-04-03 00:00:13.0    34281  30843900  1214  20230403     00:00
# 4      2023-04-02 22:59:44.0    34274  30839551  1213  20230402     00:00
# ..                       ...      ...       ...   ...       ...       ...
# 446  2022-01-05 09:01:59.247     5838    649661   749  20220105     00:00
# 447  2022-01-04 09:04:35.476     5781    645220   748  20220104     00:00
# 448  2022-01-03 08:58:35.591     5730    642199   747  20220103     00:00
# 449  2022-01-02 08:57:24.688     5694    639074   746  20220102     00:00
# 450  2022-01-01 09:02:39.218     5625    635243   745  20220101     00:00
#
#                     updateDt accExamCnt
# 0                       null        NaN
# 1                       null        NaN
# 2                       null        NaN
# 3      2023-04-03 04:18:40.0        NaN
# 4                       null        NaN
# ..                       ...        ...
# 446  2022-01-12 09:09:21.324   19778824
# 447  2022-01-12 09:09:14.713   19671880
# 448  2022-01-08 09:40:28.974   19546883
# 449  2022-01-08 09:40:16.808   19456900
# 450    2022-01-08 09:40:05.3   19364122
#
# [451 rows x 8 columns]

# %%
## openapi를 이용하여 받아온 데이터를 csv 파일 저장
corona_df.to_csv("corona.csv", encoding='UTF-8')

# %%
response = requests.get("https://www.naver.com")

# %%
pprint.pprint(response.content)
# Out:
# (b'\n<!doctype html>                          <html lang="ko" data-dark="fal'
#  b'se"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-'
#  b'UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"'
#  b'> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robo'
#  b'ts" content="index,nofollow"/> <meta name="description" content='
#  b'"\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90'
#  b'\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4'
#  b'\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90'
#  b'\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8'
#  b'\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4'
#  b'\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> '
#  b'<meta property="og:image" content="https://s.pstatic.net/static/www/mobile/e'
#  b'dit/2016/0705/mobile_212852414260.png"> <meta property="og:description" cont'
#  b'ent="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d'
#  b'\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0'
#  b'\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb'
#  b'\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3'
#  b'\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta name="twitter:card" content="summar'
#  b'y"> <meta name="twitter:title" content=""> <meta name="twitter:url" content='
#  b'"https://www.naver.com/"> <meta name="twitter:image" content="https://s.psta'
#  b'tic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta nam'
#  b'e="twitter:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb'
#  b'\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec'
#  b'\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec'
#  b'\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb'
#  b'\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>  <link rel="s'
#  b'tylesheet" href="https://pm.pstatic.net/dist/css/nmain.20230302.css"> <link '
#  b'rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_auto'
#  b'complete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/f'
#  b'avicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://'
#  b's.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-t'
#  b'ouch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.p'
#  b'ng"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;'
#  b'var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.is'
#  b'IE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("'
#  b'data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function t'
#  b'(){}return t.prototype=n,new t})</script> <script>var darkmode= false;window'
#  b'.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=win'
#  b'dow.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,windo'
#  b'w.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){windo'
#  b'w.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=wind'
#  b'ow.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){win'
#  b'dow.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script'
#  b' async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></scri'
#  b'pt> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-lo'
#  b'ader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId:'
#  b' null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleD'
#  b'om","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","s'
#  b'ingleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p'
#  b'_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"positi'
#  b'on":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"10'
#  b'00164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_d'
#  b'om_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type"'
#  b':{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LI'
#  b'VING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"'
#  b'","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https'
#  b'://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":'
#  b'"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIn'
#  b'dex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUr'
#  b'l":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living'
#  b'_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","p'
#  b'ositionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LI'
#  b'VINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUn'
#  b'it":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta'
#  b'.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"LIVINGHO'
#  b'ME_1","unit":"SU10571","calp":"-"},"type":{"position":"abs","positionIndex":'
#  b'4,"subject":"contents"},"dom":null},{"adposId":"1000186","singleDomAdUrl":"h'
#  b'ttps://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_'
#  b'2","tb":"LIVINGHOME_1","unit":"SU10572","calp":"-"},"type":{"position":"abs"'
#  b',"positionIndex":8,"subject":"contents"},"dom":null}]}},\nsvt: 2023040714'
#  b"2454,\n}; </script> <script> window.nmain.newsstand = {\nrcode: '09530102'"
#  b",\nnewsCastSubsInfo: '',\nnewsStandSubsInfo: ''\n};\nwindow.etc = {  };\n"
#  b'window.svr = "<!--aweb22-->"; </script> <script src="https://ssl.pstatic.net'
#  b'/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></scrip'
#  b't>   <script src="https://pm.pstatic.net/dist/js/external.2961eaa5.js?o=www"'
#  b' type="text/javascript" crossorigin="anonymous" defer="defer"></script> <scr'
#  b'ipt src="https://pm.pstatic.net/dist/js/preload.5fe99fda.js?o=www" type="tex'
#  b't/javascript" crossorigin="anonymous" defer="defer"></script> <script src="h'
#  b'ttps://pm.pstatic.net/dist/js/polyfill.f3c68d2d.js?o=www" type="text/javascr'
#  b'ipt" crossorigin="anonymous" defer="defer"></script>  <script src="https://p'
#  b'm.pstatic.net/dist/js/vendors~more~nmain~notice~search~sidebar_notice.40da85'
#  b'e0.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></'
#  b'script>   <script src="https://pm.pstatic.net/dist/js/search.c0c3b1c5.js?o=w'
#  b'ww" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  '
#  b'<script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notic'
#  b'e.7aad5e27.js?o=www" type="text/javascript" crossorigin="anonymous" defer="d'
#  b'efer"></script> <script src="https://pm.pstatic.net/dist/js/nmain.e31af4db.j'
#  b's?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></scri'
#  b'pt> <style>:root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}</st'
#  b'yle> </head> <body> <div id="u_skip"> <a href="#newsstand"><span'
#  b'>\xeb\x89\xb4\xec\x8a\xa4\xec\x8a\xa4\xed\x83\xa0\xeb\x93\x9c \xeb\xb0\x94'
#  b'\xeb\xa1\x9c\xea\xb0\x80\xea\xb8\xb0</span></a> <a href="#themecast"><span>'
#  b'\xec\xa3\xbc\xec\xa0\x9c\xeb\xb3\x84\xec\xba\x90\xec\x8a\xa4\xed'
#  b'\x8a\xb8 \xeb\xb0\x94\xeb\xa1\x9c\xea\xb0\x80\xea\xb8\xb0</span></a> <a hr'
#  b'ef="#timesquare"><span>\xed\x83\x80\xec\x9e\x84\xec\x8a\xa4\xed\x80\x98\xec'
#  b'\x96\xb4 \xeb\xb0\x94\xeb\xa1\x9c\xea\xb0\x80\xea\xb8\xb0</span></a> <a hr'
#  b'ef="#shopcast"><span>\xec\x87\xbc\xed\x95\x91\xec\xba\x90\xec\x8a'
#  b'\xa4\xed\x8a\xb8 \xeb\xb0\x94\xeb\xa1\x9c\xea\xb0\x80\xea\xb8\xb0</span></a>'
#  b' <a href="#account"><span>\xeb\xa1\x9c\xea\xb7\xb8\xec\x9d\xb8 '
#  b'\xeb\xb0\x94\xeb\xa1\x9c\xea\xb0\x80\xea\xb8\xb0</span></a> </div> <div id="'
#  b'wrap">         <style>._1syGnXOL{padding-right:18px;font-size:14px;line-heig'
#  b'ht:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line'
#  b'-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-alig'
#  b'n:top;background-image:url(https://static-whale.pstatic.net/main/sprite-2022'
#  b'0527@2x.png);background-repeat:no-repeat;background-size:141px 112px;width:1'
#  b'8px;height:18px;margin:16px 8px 0 0;background-position:-98px 0}[data-userag'
#  b'ent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.p'
#  b'static.net/main/sprite-20220527.png)}._1syGnXOL._3dsvmZg2:before{background-'
#  b'position:-47px -85px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;marg'
#  b'in:15px 8px 0 0;background-position:-21px -89px}._1syGnXOL._2mcQEKCd:before{'
#  b'width:22px;height:22px;margin:14px 7px 0 0;background-position:-47px -63px}.'
#  b'_1syGnXOL._36slsKuJ:before{width:21px;height:49px;margin:0 14px 0 0;backgrou'
#  b'nd-position:0 -63px}._1syGnXOL._3qlJVWzR:before{width:24px;height:49px;margi'
#  b'n:0 10px 0 0;background-position:-117px 0}._1syGnXOL._3VkgqBXB:before{width:'
#  b'26px;height:49px;margin:0 10px 0 0;background-position:-116px -54px}._1syGnX'
#  b'OL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{c'
#  b'ontent:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{displ'
#  b'ay:inline-block;position:relative;font-size:12px;height:49px;width:78px;text'
#  b'-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-al'
#  b'ign:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:b'
#  b'lock;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inli'
#  b'ne-block;content:"";vertical-align:top;background-image:url(https://static-w'
#  b'hale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;ba'
#  b'ckground-size:141px 112px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{'
#  b'background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.p'
#  b'ng)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:b'
#  b'efore{margin:9px 3px 0 0;width:17px;height:13px;background-position:-89px -6'
#  b'3px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rg'
#  b'ba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;ba'
#  b'ckground-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.'
#  b'png);background-repeat:no-repeat;background-size:141px 112px;margin-top:14px'
#  b';float:left;width:98px;height:21px;background-position:0 -21px}[data-userage'
#  b'nt*="MSIE 8"] ._1KncATpM{background-image:url(https://static-whale.pstatic.n'
#  b'et/main/sprite-20220527.png)}._1KncATpM._2v3uxv2x{background-position:0 0}._'
#  b'1KncATpM._1yl_Ow6o{background-position:0 -42px}._20PYt6lT{font-size:11px;hei'
#  b'ght:49px;cursor:pointer;position:absolute;top:0;right:0;color:#666;opacity:.'
#  b'7}._20PYt6lT:after{width:15px;height:15px;margin-left:4px;background-positio'
#  b'n:-98px -33px;display:inline-block;content:"";vertical-align:top;background-'
#  b'image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);back'
#  b'ground-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8'
#  b'"] ._20PYt6lT:after{background-image:url(https://static-whale.pstatic.net/ma'
#  b'in/sprite-20220527.png)}._20PYt6lT._39oMCV2N:after{background-position:-98px'
#  b' -18px}._20PYt6lT._3MOWOORv{color:#c3c2c2}._20PYt6lT._3MOWOORv:after{backgro'
#  b'und-position:-80px -85px}._20PYt6lT._3wm5EzmJ{color:#fff}._20PYt6lT._3wm5Ezm'
#  b'J:after{background-position:-65px -85px}._1hiMWemA{height:49px}._1hiMWemA .t'
#  b'Y_u8r23{position:relative;width:1130px;margin:0 auto}._1hiMWemA .tY_u8r23 a{'
#  b'text-decoration:none}._1hiMWemA._23U_6TM_{position:relative}._1hiMWemA._23U_'
#  b'6TM_:after{position:absolute;z-index:1;content:"";display:block;width:100%;h'
#  b'eight:1px;bottom:0;background-color:rgba(0,0,0,.050980392156862744)}</style>'
#  b'\n<div\nid="NM_TOP_BANNER"\ndata-clk-prefix="top"\nclass="_1hiMWemA"\nsty'
#  b'le="background-color: #fff7e1"\n>\n<div class="tY_u8r23">\n<a\nclass="_3h-N8'
#  b'T9V"\nhref="https://whale.naver.com/ko/details/security/&wpid=RydDy7"\ndat'
#  b'a-clk="dropbanner1a"\n></a\n><span\nclass="_1syGnXOL _3VkgqBXB"\ndata-clk="d'
#  b'ropbanner1a"\nstyle="padding-right: 20px; font-size: 17px; color: black"\n'
#  b'><span>\xeb\xa7\xa4\xec\x9d\xbc \xec\x93\xb0\xeb\x8a\x94 \xeb\xb8\x8c'
#  b'\xeb\x9d\xbc\xec\x9a\xb0\xec\xa0\x80 \xeb\xb3\xb4\xec\x95\x88\xec\x9d\xb4 '
#  b'\xea\xb1\xb1\xec\xa0\x95\xeb\x90\x9c\xeb\x8b\xa4\xeb\xa9\xb4, </span\n><st'
#  b'rong\n>\xec\x95\x88\xec\xa0\x84\xed\x95\x98\xea\xb3\xa0 \xeb\xb9\xa0\xeb\xa5'
#  b'\xb8 \xec\xb5\x9c\xec\x8b\xa0 \xeb\xb8\x8c\xeb\x9d\xbc\xec\x9a\xb0\xec\xa0'
#  b'\x80 \xec\x9b\xa8\xec\x9d\xbc\xeb\xa1\x9c \xec\x97\x85\xeb\x8d\xb0\xec\x9d'
#  b'\xb4\xed\x8a\xb8 \xed\x95\x98\xec\x84\xb8\xec\x9a\x94.</strong\n></span\n'
#  b'><a\nhref="https://installer-whale.pstatic.net/downloads/banner/RydDy7/Wh'
#  b'aleSetup.exe"\nclass="_2aeXMlrb BMgpjddw"\nid="NM_whale_download_btn"\ndata'
#  b'-clk="dropdownload1a"\n><span style="background-color: #0436c7">\xeb'
#  b'\x8b\xa4\xec\x9a\xb4\xeb\xa1\x9c\xeb\x93\x9c</span></a\n><button\ntype="but'
#  b'ton"\ndata-ui-cookie-exp-days="3"\ndata-ui-cookie-key="NM_TOP_PROMOTION"\nd'
#  b'ata-ui-cookie-value="1"\ndata-ui-hide-target="#NM_TOP_BANNER"\ndata-clk="d'
#  b'ropclose1a"\nclass="_20PYt6lT _39oMCV2N"\n>\n3\xec\x9d\xbc \xeb'
#  b'\x8f\x99\xec\x95\x88 \xeb\xb3\xb4\xec\xa7\x80 \xec\x95\x8a\xea\xb8\xb0\n</bu'
#  b'tton>\n</div>\n</div>\n  <div id="header" role="banner">\n\n\n\n\n\n\n\n\n<d'
#  b'iv class="special_bg">\n<div class="group_flex">\n<div class="logo_area">\n'
#  b'<h1 class="logo_default">\n<a href="/" class="logo_naver" data-clk="top.l'
#  b'ogo"\n><span class="blind">\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84</span></'
#  b'a\n>\n</h1>\n</div>\n<div class="service_area">\n<a id="NM_set_home_btn" '
#  b'href="https://help.naver.com/support/welcomePage/guide.help" class="link_set'
#  b'" data-clk="top.mkhome">\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84\xeb\xa5\xbc'
#  b' \xec\x8b\x9c\xec\x9e\x91\xed\x8e\x98\xec\x9d\xb4\xec\xa7\x80\xeb\xa1\x9c<'
#  b'/a>\n<i class="sa_bar"></i>\n<a href="https://jr.naver.com" class="link_jr'
#  b'naver" data-clk="top.jrnaver"><i class="ico_jrnaver"></i><span class="blind"'
#  b'>\xec\xa5\xac\xeb\x8b\x88\xec\x96\xb4\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84<'
#  b'/span></a>\n<a href="https://happybean.naver.com" class="link_happybin" d'
#  b'ata-clk="top.happybean"><i class="ico_happybin"></i><span class="blind">'
#  b'\xed\x95\xb4\xed\x94\xbc\xeb\xb9\x88</span></a>\n</div>\n\n<div id="search'
#  b'" class="search_area" data-clk-prefix="sch">\n<form id="sform" name="sfor'
#  b'm" action="https://search.naver.com/search.naver" method="get" role="search"'
#  b'>\n<fieldset>\n<legend class="blind">\xea\xb2\x80\xec\x83\x89</legend>\n<'
#  b'input type="hidden" name="where" value="nexearch" />\n<input type="hidden'
#  b'" id="sm" name="sm" value="top_hty" />\n<input type="hidden" id="fbm" nam'
#  b'e="fbm" value="0" />\n<input type="hidden" id="acr" name="acr" value="" d'
#  b'isabled="disabled" />\n<input type="hidden" id="acq" name="acq" value="" '
#  b'disabled="disabled" />\n<input type="hidden" id="qdt" name="qdt" value=""'
#  b' disabled="disabled" />\n<input type="hidden" id="ie" name="ie" value="ut'
#  b'f8" />\n<input type="hidden" id="acir" name="acir" value="" disabled="dis'
#  b'abled" />\n<input type="hidden" id="os" name="os" value="" disabled="disa'
#  b'bled" />\n<input type="hidden" id="bid" name="bid" value="" disabled="dis'
#  b'abled" />\n<input type="hidden" id="pkid" name="pkid" value="" disabled="'
#  b'disabled" />\n<input type="hidden" id="eid" name="eid" value="" disabled='
#  b'"disabled" />\n<input type="hidden" id="mra" name="mra" value="" disabled'
#  b'="disabled" />\n\n\n\n<div class="green_window" style=\'\'>\n<!-- [AU] data'
#  b'-atcmp-element \xec\x97\x90 \xed\x95\xb4\xeb\x8b\xb9\xed\x95\x98'
#  b'\xeb\x8a\x94 attribute\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed'
#  b'\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<input id="query" name='
#  b'"query" type="search" title="\xea\xb2\x80\xec\x83\x89\xec\x96\xb4 \xec'
#  b'\x9e\x85\xeb\xa0\xa5" maxlength="255" class="input_text" tabindex="1" acces'
#  b'skey="s" style="ime-mode:active;" autocomplete="off"  placeholder="\xea'
#  b'\xb2\x80\xec\x83\x89\xec\x96\xb4\xeb\xa5\xbc \xec\x9e\x85\xeb'
#  b'\xa0\xa5\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94." onclick="docum'
#  b'ent.getElementById(\'fbm\').value=1;" value="" data-atcmp-element>\n</div>\n'
#  b'<button id="search_btn" type="submit" title="\xea\xb2\x80\xec\x83\x89" tab'
#  b'index="3" class="btn_submit" onclick="window.nclick(this,\'sch.action\',\'\''
#  b',\'\',event);" style=\'\'>\n<span class="blind">\xea\xb2\x80\xec\x83\x89</s'
#  b'pan>\n<span class="ico_search_submit"></span>\n</button>\n</fieldset>\n</for'
#  b'm>\n<!-- \xed\x95\x9c\xea\xb8\x80\xec\x9e\x85\xeb\xa0\xa5\xea\xb8\xb0 -->\n'
#  b'<a href="#" id="ke_kbd_btn" role="button" class="btn_keyboard" onclick="retu'
#  b'rn false;"><span class="blind">\xed\x95\x9c\xea\xb8\x80 \xec\x9e'
#  b'\x85\xeb\xa0\xa5\xea\xb8\xb0</span><span class="ico_keyboard"></span></a>'
#  b'\n<div id="_nx_kbd" style="display:none;"></div>\n<div class="autocomplete'
#  b'">\n<!-- \xec\x9e\x90\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1 \xec\x97\xb4'
#  b'\xeb\xa6\xb0 \xea\xb2\xbd\xec\x9a\xb0 fold \xed\x81\xb4\xeb\x9e\x98\xec\x8a'
#  b'\xa4 \xec\xb6\x94\xea\xb0\x80, \xeb\x94\xa4\xeb\x93\x9c\xec\x9d\xb8 '
#  b'\xea\xb2\xbd\xec\x9a\xb0 dim \xec\xb6\x94\xea\xb0\x80 -->\n<a href="#" ro'
#  b'le="button" id="nautocomplete" tabindex="2" class="btn_arw _btn_arw fold" ar'
#  b'ia-pressed="false" data-atcmp-element><span class="blind">\xec\x9e'
#  b'\x90\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1 \xeb\xa0\x88\xec\x9d'
#  b'\xb4\xec\x96\xb4</span><span class="ico_arr"></span></a>\n</div>\n<!--'
#  b' \xec\x9e\x90\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1\xeb\xa0\x88'
#  b'\xec\x9d\xb4\xec\x96\xb4 -->\n<div id="autoFrame" class="reatcmp" style="di'
#  b'splay: none;">\n<!-- [AU] data-atcmp-element attribute\xeb\xa5\xbc'
#  b' \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94.'
#  b' -->\n<div class="ly_atcmp" data-atcmp-element>\n<div class="api_atcmp_wra'
#  b'p">\n<!-- \xec\xb5\x9c\xea\xb7\xbc\xea\xb2\x80\xec\x83\x89\xec\x96\xb4 -->'
#  b'\n<!-- [AU] _recent_layer \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5'
#  b'\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84'
#  b'\xb8\xec\x9a\x94. -->\n<div class="atcmp_fixer _recent_layer" style="disp'
#  b'lay:none;">\n<!-- [AU] _recent_header \xed\x81\xb4\xeb\x9e\x98\xec'
#  b'\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec'
#  b'\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<div class="atcmp_header _recent_h'
#  b'eader">\n<strong class="tit">\xec\xb5\x9c\xea\xb7\xbc\xea\xb2'
#  b'\x80\xec\x83\x89\xec\x96\xb4</strong>\n<div class="option">\n<!-- [AU] _del'
#  b'All \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94'
#  b'\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<a role'
#  b'="button" href="#" class="item _delAll" aria-pressed="false">\xec\xa0\x84'
#  b'\xec\xb2\xb4\xec\x82\xad\xec\xa0\x9c</a>\n</div>\n</div>\n<div class="atcm'
#  b'p_container">\n<!-- [AU] _recent \xed\x81\xb4\xeb\x9e\x98\xec\x8a'
#  b'\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3'
#  b'\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<ul class="kwd_lst _recent">\n<!-- \xec'
#  b'\xb5\x9c\xea\xb7\xbc\xea\xb2\x80\xec\x83\x89\xec\x96\xb4 \xed'
#  b'\x85\x9c\xed\x94\x8c\xeb\xa6\xbf -->\n<!-- [AU] _item \xed\x81\xb4'
#  b'\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80'
#  b'\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [AU] data-tem'
#  b'plate-type="history" data-keyword="@in_txt@" attribute\xeb\xa5\xbc \xec\xb6'
#  b'\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<l'
#  b'i class="item _item" data-rank="@rank@" data-template-type="history" data-ke'
#  b'yword="@in_txt@">\n<a href="#" class="kwd">\n<span class="fix"><span class'
#  b'="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></'
#  b'span>\n</a>\n<span class="etc">\n<em class="date">@date@.</em>\n<!-- [AU] _d'
#  b'el \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea'
#  b'\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<a href="#" '
#  b'role="button" class="bt_item _del" aria-pressed="false"><i class="imsc ico_d'
#  b'el">\xec\x82\xad\xec\xa0\x9c</i></a>\n</span>\n</li>\n</ul>\n<!-- [D] '
#  b'\xea\xb2\x80\xec\x83\x89\xec\x96\xb4 \xec\xa0\x80\xec\x9e\xa5 \xea\xba\xbc'
#  b'\xec\xa7\x84 \xea\xb2\xbd\xec\x9a\xb0 atcmp_fixer\xec\x97\x90 type_off \xec'
#  b'\xb6\x94\xea\xb0\x80 -->\n<!-- [AU] _offMsg \xed\x81\xb4\xeb\x9e\x98\xec\x8a'
#  b'\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3'
#  b'\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<div class="kwd_info kwd_off _offMsg" s'
#  b'tyle="display: none;">\xea\xb2\x80\xec\x83\x89\xec\x96\xb4 \xec\xa0\x80\xec'
#  b'\x9e\xa5 \xea\xb8\xb0\xeb\x8a\xa5\xec\x9d\xb4 \xea\xba\xbc\xec\xa0\xb8 '
#  b'\xec\x9e\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.<br><span class="kwd_ds'
#  b'c">\xec\x84\xa4\xec\xa0\x95\xec\x9d\xb4 \xec\xb4\x88\xea\xb8\xb0\xed'
#  b'\x99\x94 \xeb\x90\x9c\xeb\x8b\xa4\xeb\xa9\xb4 <a href="https://help.naver'
#  b'.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly'
#  b'.help" target="_blank">\xeb\x8f\x84\xec\x9b\x80\xeb\xa7\x90</a>\xec\x9d\x84 '
#  b'\xed\x99\x95\xec\x9d\xb8\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94.<'
#  b'/span></div>\n<!-- [D] \xea\xb2\x80\xec\x83\x89\xec\x96\xb4 \xeb\x82\xb4\xec'
#  b'\x97\xad \xec\x97\x86\xeb\x8a\x94 \xea\xb2\xbd\xec\x9a\xb0 atcmp_fixer'
#  b'\xec\x97\x90 type_off \xec\xb6\x94\xea\xb0\x80 -->\n<!-- [AU] _recentNon'
#  b'e \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0'
#  b'\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<div class="kwd_i'
#  b'nfo kwd_none _recentNone" style="display: none;">\xec\xb5\x9c\xea\xb7\xbc '
#  b'\xea\xb2\x80\xec\x83\x89\xec\x96\xb4 \xeb\x82\xb4\xec\x97\xad\xec\x9d\xb4 '
#  b'\xec\x97\x86\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.<br><span class="kwd_ds'
#  b'c">\xec\x84\xa4\xec\xa0\x95\xec\x9d\xb4 \xec\xb4\x88\xea\xb8\xb0\xed'
#  b'\x99\x94 \xeb\x90\x9c\xeb\x8b\xa4\xeb\xa9\xb4 <a href="https://help.naver'
#  b'.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly'
#  b'.help" target="_blank">\xeb\x8f\x84\xec\x9b\x80\xeb\xa7\x90</a>\xec\x9d\x84 '
#  b'\xed\x99\x95\xec\x9d\xb8\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94.<'
#  b'/span></div>\n</div>\n<div class="atcmp_footer">\n<span class="side_opt_are'
#  b'a">\n<span class="opt_item"><a href="https://help.naver.com/support/servi'
#  b'ce/main.help?serviceNo=605&amp;categoryNo=1991" data-clk="sly.help" target="'
#  b'_blank">\xeb\x8f\x84\xec\x9b\x80\xeb\xa7\x90</a></span>\n</span>\n<span c'
#  b'lass="rside_opt_area">\n<span class="opt_item">\n<!-- [AU] _keywordOnO'
#  b'ff \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea'
#  b'\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<a href="#" '
#  b'class="close _keywordOnOff">\xec\x9e\x90\xeb\x8f\x99\xec\xa0\x80\xec\x9e\xa5'
#  b' \xeb\x81\x84\xea\xb8\xb0</a>\n</span>\n</span>\n</div>\n</div>\n<!-- \xec'
#  b'\x9e\x90\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1 -->\n<!-- [AU] _atcmp_lay'
#  b'er \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea'
#  b'\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<div class="'
#  b'atcmp_fixer _atcmp_layer" style="display:none;">\n<!-- [AU] _words \xed\x81'
#  b'\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0'
#  b'\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<div class="atcmp'
#  b'_container _words">\n<!-- \xec\xa0\x95\xeb\x8b\xb5\xed\x98\x95 \xed'
#  b'\x85\x9c\xed\x94\x8c\xeb\xa6\xbf : \xeb\xa1\x9c\xeb\x98\x90\xeb\x8b\xb9'
#  b'\xec\xb2\xa8\xeb\xb2\x88\xed\x98\xb8 -->\n<!-- [AU] _answer \xed\x81\xb4\xeb'
#  b'\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed'
#  b'\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [AU] data-template'
#  b'-type="answer_3" data-code="@code@" data-keyword="@1@" attribute'
#  b'\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc'
#  b'\xec\x84\xb8\xec\x9a\x94. -->\n<div class="atcmp_correct type_lotto _answer'
#  b'" data-template-type="answer_3" data-code="@code@" data-keyword="@1@">\n<'
#  b'a href="#" class="link_item">\n<span class="common_ico_kwd"><i class="ims'
#  b'c ico_search"></i></span>\n<div class="dsc_area">\n<span class="tit">@'
#  b'5@\xed\x9a\x8c \xeb\xa1\x9c\xeb\x98\x90\xeb\x8b\xb9\xec\xb2\xa8\xeb\xb2'
#  b'\x88\xed\x98\xb8</span>\n<span class="dsc">\n<span class="item">\xeb\x8f'
#  b'\x99\xed\x96\x89\xeb\xb3\xb5\xea\xb6\x8c \xec\xa0\x9c\xea\xb3\xb5</span>'
#  b'\n</span>\n</div>\n<span class="etc_area">\n<span class="etc lotto">\n<em'
#  b' class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em '
#  b'class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><'
#  b'em class="imsc_bf bonus n@12@">@12@</em>\n</span>\n</span>\n</a>\n</div>'
#  b'\n<!-- \xec\xa0\x95\xeb\x8b\xb5\xed\x98\x95 \xed\x85\x9c\xed\x94\x8c\xeb\xa6'
#  b'\xbf : \xed\x99\x98\xec\x9c\xa8 -->\n<!-- [AU] _answer \xed\x81\xb4'
#  b'\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80'
#  b'\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [AU] data-tem'
#  b'plate-type="answer_9" data-code="@code@" data-keyword="@1@" attribut'
#  b'e\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8'
#  b'\xec\x9a\x94. -->\n<div class="atcmp_correct type_exchange _answer" data-t'
#  b'emplate-type="answer_9" data-code="@code@" data-keyword="@1@">\n<!-- [D] '
#  b'\xec\x83\x81\xec\x8a\xb9 up, \xed\x95\x98\xeb\x9d\xbd down \xec'
#  b'\xb6\x94\xea\xb0\x80 -->\n<a href="#" class="link_item @11@">\n<!-- [D] \xea'
#  b'\xb5\xad\xea\xb0\x80\xeb\xb3\x84 class \xea\xb0\x80\xeb\x82\x98\xeb\x8b\xa4'
#  b'\xec\x88\x9c\nZAR \xeb\x82\xa8\xec\x95\x84\xed\x94\x84\xeb\xa6\xac'
#  b'\xec\xb9\xb4 \xea\xb3\xb5\xed\x99\x94\xea\xb5\xad\nNPR \xeb\x84'
#  b'\xa4\xed\x8c\x94\nNOK \xeb\x85\xb8\xeb\xa5\xb4\xec\x9b\xa8\xec\x9d\xb4\nNZ'
#  b'D \xeb\x89\xb4\xec\xa7\x88\xeb\x9e\x9c\xeb\x93\x9c\nTWD \xeb\x8c\x80\xeb\xa7'
#  b'\x8c\nDKK \xeb\x8d\xb4\xeb\xa7\x88\xed\x81\xac\nRUB \xeb\x9f\xac\xec'
#  b'\x8b\x9c\xec\x95\x84\nMOP \xeb\xa7\x88\xec\xb9\xb4\xec\x98\xa4\nMYR '
#  b'\xeb\xa7\x90\xeb\xa0\x88\xec\x9d\xb4\xec\x8b\x9c\xec\x95\x84\nMXN '
#  b'\xeb\xa9\x95\xec\x8b\x9c\xec\xbd\x94\nMNT \xeb\xaa\xbd\xea\xb3\xa8\nUSD'
#  b' \xeb\xaf\xb8\xea\xb5\xad\nBHD \xeb\xb0\x94\xeb\xa0\x88\xec\x9d\xb8\nBD'
#  b'T \xeb\xb0\xa9\xea\xb8\x80\xeb\x9d\xbc\xeb\x8d\xb0\xec\x8b\x9c\nVND \xeb\xb2'
#  b'\xa0\xed\x8a\xb8\xeb\x82\xa8\nBRL \xeb\xb8\x8c\xeb\x9d\xbc\xec\xa7\x88\nSA'
#  b'R \xec\x82\xac\xec\x9a\xb0\xeb\x94\x94\xec\x95\x84\xeb\x9d\xbc\xeb\xb9\x84'
#  b'\xec\x95\x84\nSEK \xec\x8a\xa4\xec\x9b\xa8\xeb\x8d\xb4\nCHF \xec\x8a'
#  b'\xa4\xec\x9c\x84\xec\x8a\xa4\nSGD \xec\x8b\xb1\xea\xb0\x80\xed\x8f'
#  b'\xac\xeb\xa5\xb4\nAED \xec\x95\x84\xeb\x9e\x8d\xec\x97\x90\xeb\xaf'
#  b'\xb8\xeb\xa6\xac\xed\x8a\xb8\nGBP \xec\x98\x81\xea\xb5\xad\nEUR \xec'
#  b'\x9c\xa0\xeb\x9f\xbd\xec\x97\xb0\xed\x95\xa9\nILS \xec\x9d\xb4\xec'
#  b'\x8a\xa4\xeb\x9d\xbc\xec\x97\x98\nEGP \xec\x9d\xb4\xec\xa7\x91\xed'
#  b'\x8a\xb8\nINR \xec\x9d\xb8\xeb\x8f\x84\nIDR \xec\x9d\xb8\xeb\x8f\x84'
#  b'\xeb\x84\xa4\xec\x8b\x9c\xec\x95\x84\nJPY \xec\x9d\xbc\xeb\xb3\xb8\nCNY'
#  b' \xec\xa4\x91\xea\xb5\xad\nCZK \xec\xb2\xb4\xec\xbd\x94\nCLP \xec'
#  b'\xb9\xa0\xeb\xa0\x88\nKZT \xec\xb9\xb4\xec\x9e\x90\xed\x9d\x90\xec'
#  b'\x8a\xa4\xed\x83\x84\nQAR \xec\xb9\xb4\xed\x83\x80\xeb\xa5\xb4\nCAD '
#  b'\xec\xba\x90\xeb\x82\x98\xeb\x8b\xa4\nKWD \xec\xbf\xa0\xec\x9b\xa8'
#  b'\xec\x9d\xb4\xed\x8a\xb8\nTHB \xed\x83\x9c\xea\xb5\xad\nTRY \xed\x84'
#  b'\xb0\xed\x82\xa4\nPKR \xed\x8c\x8c\xed\x82\xa4\xec\x8a\xa4\xed\x83\x84\nPL'
#  b'N \xed\x8f\xb4\xeb\x9e\x80\xeb\x93\x9c\nPHP \xed\x95\x84\xeb\xa6\xac\xed\x95'
#  b'\x80\nHUF \xed\x97\x9d\xea\xb0\x80\xeb\xa6\xac\nAUD \xed\x98\xb8\xec'
#  b'\xa3\xbc\nHKD \xed\x99\x8d\xec\xbd\xa9\n-->\n<span class="common_ico_kwd"><'
#  b'i class="imsc ico @12@">@14@</i></span>\n<div class="dsc_area">\n<span cla'
#  b'ss="tit">@txt@<span class="sub">@currency@</span></span>\n<span class="ds'
#  b'c">\n<span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>\n</sp'
#  b'an>\n</div>\n<span class="etc_area">\n<span class="etc"><em class="num">@6@'
#  b'</em>\xec\x9b\x90</span>\n</span>\n</a>\n</div>\n<!-- \xec\xa0\x95'
#  b'\xeb\x8b\xb5\xed\x98\x95 \xed\x85\x9c\xed\x94\x8c\xeb\xa6\xbf : \xeb'
#  b'\x82\xa0\xec\x94\xa8(\xea\xb5\xad\xeb\x82\xb411, \xed\x95\xb4\xec\x99\xb812'
#  b') -->\n<!-- [AU] _answer \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc'
#  b' \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94.'
#  b' -->\n<!-- [AU] data-template-type="answer_11" data-code="@code@" data-ke'
#  b'yword="@1@" attribute\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed'
#  b'\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<div class="atcmp_corre'
#  b'ct type_weather _answer" data-template-type="answer_11" data-code="@code@" d'
#  b'ata-keyword="@1@">\n<!-- [D] \xec\x83\x81\xec\x8a\xb9 up, \xed'
#  b'\x95\x98\xeb\x9d\xbd down \xec\xb6\x94\xea\xb0\x80 -->\n<a href="#" class='
#  b'"link_item @12@">\n<span class="common_ico_kwd"><i class="imsc ico_search'
#  b'"></i></span>\n<div class="dsc_area">\n<span class="tit">@txt@</span>\n<spa'
#  b'n class="dsc">\n<span class="item">@7@, @message@</span>\n</span>\n</div>\n<'
#  b'span class="etc_area">\n<span class="etc">\n<!-- [D] \xeb\x82\xa0\xec\x94'
#  b'\xa8\xeb\xb3\x84 class\nico1 \xeb\xa7\x91\xec\x9d\x8c(\xeb\x82\xae)\nico2'
#  b' \xeb\xa7\x91\xec\x9d\x8c(\xeb\xb0\xa4)\nico3 \xea\xb5\xac\xeb\xa6\x84'
#  b'\xec\xa1\xb0\xea\xb8\x88(\xeb\x82\xae)\nico4 \xea\xb5\xac\xeb\xa6\x84\xec'
#  b'\xa1\xb0\xea\xb8\x88(\xeb\xb0\xa4)\nico5 \xea\xb5\xac\xeb\xa6\x84\xeb\xa7'
#  b'\x8e\xec\x9d\x8c(\xeb\x82\xae)\nico6 \xea\xb5\xac\xeb\xa6\x84\xeb\xa7\x8e'
#  b'\xec\x9d\x8c(\xeb\xb0\xa4)\nico7 \xed\x9d\x90\xeb\xa6\xbc\nico8 \xec\x95'
#  b'\xbd\xed\x95\x9c\xeb\xb9\x84\nico9 \xeb\xb9\x84\nico10 \xea\xb0\x95\xed\x95'
#  b'\x9c\xeb\xb9\x84\nico11 \xec\x95\xbd\xed\x95\x9c\xeb\x88\x88\nico12 \xeb'
#  b'\x88\x88\nico13 \xea\xb0\x95\xed\x95\x9c\xeb\x88\x88\nico14 \xec\xa7\x84'
#  b'\xeb\x88\x88\xea\xb9\xa8\xeb\xb9\x84\nico15 \xec\x86\x8c\xeb\x82\x98\xea\xb8'
#  b'\xb0\nico16 \xec\x95\x88\xea\xb0\x9c\nico17 \xec\x86\x8c\xeb\x82\x99\xeb'
#  b'\x88\x88\nico18 \xeb\xb2\x88\xea\xb0\x9c\xeb\x87\x8c\xec\x9a\xb0\nico19 '
#  b'\xec\x9a\xb0\xeb\xb0\x95\nico20 \xed\x99\xa9\xec\x82\xac\nico21 \xeb\xb9'
#  b'\x84\xeb\x98\x90\xeb\x8a\x94\xeb\x88\x88\nico22 \xea\xb0\x80\xeb\x81\x94\xeb'
#  b'\xb9\x84\nico23 \xea\xb0\x80\xeb\x81\x94\xeb\x88\x88\nico24 \xea\xb0\x80'
#  b'\xeb\x81\x94\xeb\xb9\x84\xeb\x98\x90\xeb\x8a\x94\xeb\x88\x88\nico25 \xed\x9d'
#  b'\x90\xeb\xa6\xb0\xed\x9b\x84\xea\xb0\xac\nico26 \xeb\x87\x8c\xec\x9a\xb0\xed'
#  b'\x9b\x84\xea\xb0\xac\nico27 \xeb\xb9\x84\xed\x9b\x84\xea\xb0\xac\nico28 '
#  b'\xeb\x88\x88\xed\x9b\x84\xea\xb0\xac\nico29 \xed\x9d\x90\xeb\xa0\xa4\xec\xa0'
#  b'\xb8\xeb\xb9\x84\nico30 \xed\x9d\x90\xeb\xa0\xa4\xec\xa0\xb8\xeb\x88\x88\n'
#  b'-->\n<span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></s'
#  b'pan>\n<em class="degree">@8@<sup class="celsius">\xc2\xb0</sup></em>\n</span'
#  b'>\n</span>\n</a>\n</div>\n<!-- \xec\xa0\x95\xeb\x8b\xb5\xed\x98\x95'
#  b' \xed\x85\x9c\xed\x94\x8c\xeb\xa6\xbf : \xec\x82\xac\xec\x9d\xb4\xed'
#  b'\x8a\xb8 \xeb\xb0\x94\xeb\xa1\x9c\xea\xb0\x80\xea\xb8\xb0 -->\n<!-- [AU] _a'
#  b'nswer \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0'
#  b'\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [AU] data-te'
#  b'mplate-type="answer_17" data-code="@code@" data-keyword="@1@" attribute\xeb'
#  b'\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec'
#  b'\x84\xb8\xec\x9a\x94. -->\n<div class="atcmp_correct type_site _answer" data'
#  b'-template-type="answer_17" data-code="@code@" data-keyword="@1@">\n<a hre'
#  b'f="@5@" class="link_item" target="_blank">\n<span class="common_ico_kwd">'
#  b'<i class="imsc ico_url"></i></span>\n<div class="dsc_area">\n<span class="'
#  b'tit">@txt@</span>\n<span class="dsc">\n<span class="item">@5@</span>\n</spa'
#  b'n>\n</div>\n<span class="etc_area">\n<span class="etc">\xeb\xb0\x94\xeb'
#  b'\xa1\x9c\xea\xb0\x80\xea\xb8\xb0</span>\n</span>\n</a>\n</div>\n<!-- [AU] _k'
#  b'wd_list \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94'
#  b'\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<ul cla'
#  b'ss="kwd_lst _kwd_list">\n<!-- [AU] \xec\x9e\x90\xeb\x8f\x99\xec\x99\x84\xec'
#  b'\x84\xb1 \xea\xb2\x80\xec\x83\x89\xec\x96\xb4 \xed\x85\x9c\xed\x94\x8c\xeb'
#  b'\xa6\xbf -->\n<!-- [AU] _item \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4'
#  b'\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc'
#  b'\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [AU] data-rank="@rank@" data-template-t'
#  b'ype="suggestion" data-keyword="@in_txt@" attribute\xeb\xa5\xbc \xec\xb6'
#  b'\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<l'
#  b'i class="item _item" data-rank="@rank@" data-template-type="suggestion" data'
#  b'-keyword="@in_txt@">\n<a href="#" class="kwd">\n<span class="fix"><span cl'
#  b'ass="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>\n'
#  b'</a>\n<span class="etc">\n<a href="#" role="button" class="bt_item _add" a'
#  b'ria-pressed="false"><i class="imsc ico_insert">\xec\xb6\x94\xea\xb0\x80</i'
#  b'></a>\n</span>\n</li>\n<!-- [AU] \xec\xb5\x9c\xea\xb7\xbc\xea\xb2\x80\xec'
#  b'\x83\x89\xec\x96\xb4 \xed\x85\x9c\xed\x94\x8c\xeb\xa6\xbf -->\n<!-- [AU] _i'
#  b'tem \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94'
#  b'\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [A'
#  b'U] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" a'
#  b'ttribute\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc'
#  b'\xec\x84\xb8\xec\x9a\x94. -->\n<li class="item has_correct _item" data-rank'
#  b'="@rank@" data-template-type="history" data-keyword="@in_txt@">\n<a href='
#  b'"#" class="kwd">\n<span class="fix"><span class="common_ico_kwd"><i class'
#  b'="imsc ico_search"></i></span>@txt@</span>\n</a>\n<span class="etc">\n<!-- '
#  b'\xec\xb5\x9c\xea\xb7\xbc\xea\xb2\x80\xec\x83\x89\xec\x96\xb4 '
#  b'\xec\x9e\x88\xec\x9c\xbc\xeb\xa9\xb4 \xeb\x82\xa0\xec\xa7\x9c \xed\x91\x9c'
#  b'\xec\x8b\x9c -->\n<em class="date">@date@.</em>\n<a href="#" role="button" '
#  b'class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert"'
#  b'>\xec\xb6\x94\xea\xb0\x80</i></a>\n</span>\n</li>\n</ul>\n<!-- [AU] \xeb\xac'
#  b'\xb8\xeb\xa7\xa5\xea\xb2\x80\xec\x83\x89 \xed\x85\x9c\xed\x94'
#  b'\x8c\xeb\xa6\xbf -->\n<!-- [AU] _item \xed\x81\xb4\xeb\x9e\x98\xec'
#  b'\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec'
#  b'\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [AU] data-rank="@rank@" data-'
#  b'template-type="intend" data-keyword="@transQuery@" attribute\xeb\xa5\xbc '
#  b'\xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. '
#  b'-->\n<li class="item has_correct _item" data-rank="@rank@" data-intend-ra'
#  b'nk="@intendRank@" data-template-type="intend" data-keyword="@transQuery@'
#  b'">\n<a href="#" class="kwd">\n<span class="fix"><span class="common_ico_kw'
#  b'd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@inte'
#  b'nd@</span></span>\n</a>\n<span class="etc">\n<a href="#" role="button" clas'
#  b's="bt_item _add" aria-pressed="false"><i class="imsc ico_insert"'
#  b'>\xec\xb6\x94\xea\xb0\x80</i></a>\n</span>\n</li>\n<!-- [D] \xec'
#  b'\x84\xa0\xea\xb1\xb0\xec\x95\x88\xeb\x82\xb4\xeb\xac\xb8\xea\xb5\xac -->\n<!'
#  b'-- [AU] _alert \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc '
#  b'\xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. '
#  b'-->\n<div class="atcmp_alert _alert">\n<div class="dsc_election">\n<p class'
#  b'="dsc">\n<i class="imsc ico_election"></i><span class="_alert_passage"></'
#  b'span>\n</p>\n<span class="dsc_inner">\n<!-- [AU] _alert_passage2 \xed\x81'
#  b'\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0'
#  b'\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<span class="_ale'
#  b'rt_passage2"></span>\n<!-- [AU] _alert_link \xed\x81\xb4\xeb\x9e'
#  b'\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95'
#  b'\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<a href="#" class="link _ale'
#  b'rt_link" target="_blank">\xec\x9e\x90\xec\x84\xb8\xed\x9e\x88\xeb\xb3'
#  b'\xb4\xea\xb8\xb0</a>\n</span>\n</div>\n</div>\n<!-- [AU] _plus \xed'
#  b'\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea'
#  b'\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<div class="'
#  b'atcmp_plus _plus">\n<div class="dsc_plus">\n<a href="https://help.naver.co'
#  b'm/support/alias/search/word/word_16.naver" class="link_dsc" data-clk="sug.cx'
#  b'help" target="_blank">\xea\xb4\x80\xec\x8b\xac\xec\x82\xac\xeb\xa5\xbc \xeb'
#  b'\xb0\x98\xec\x98\x81\xed\x95\x9c \xec\xbb\xa8\xed\x85\x8d\xec'
#  b'\x8a\xa4\xed\x8a\xb8 \xec\x9e\x90\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1<i cla'
#  b'ss="imsc ico_help">\xeb\x8f\x84\xec\x9b\x80\xeb\xa7\x90</i></a>\n</div>\n'
#  b'<div class="switch">\n<!-- [D] \xec\x84\xa0\xed\x83\x9d\xec\x8b\x9c aria-pre'
#  b'ssed="ture/false" -->\n<!-- [AU] _plus_btn \xed\x81\xb4\xeb\x9e\x98'
#  b'\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4'
#  b'\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<a role="button" href="#" class="'
#  b'bt_switch active _plus_btn" aria-pressed="false"><i class="imsc ico_option">'
#  b'\xec\xbb\xa8\xed\x85\x8d\xec\x8a\xa4\xed\x8a\xb8 \xec\x9e\x90'
#  b'\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1</i></a>\n</div>\n<!-- [AU] _plus_lay'
#  b'er \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea'
#  b'\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<div class="'
#  b'layer_plus _plus_layer">\n<strong class="tit">\xec\xbb\xa8\xed\x85\x8d\xec'
#  b'\x8a\xa4\xed\x8a\xb8 \xec\x9e\x90\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1</stro'
#  b'ng>\n<!-- [AU] _plus_layer_isloggedin \xed\x81\xb4\xeb\x9e\x98\xec'
#  b'\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec'
#  b'\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [AU] style="display:none"'
#  b' \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94.'
#  b' -->\n<div class="_plus_layer_isloggedin" style="display:none">\n<p class='
#  b'"dsc">ON/OFF \xec\x84\xa4\xec\xa0\x95\xec\x9d\x80<br>\xed\x95'
#  b'\xb4\xeb\x8b\xb9\xea\xb8\xb0\xea\xb8\xb0(\xeb\xb8\x8c\xeb\x9d'
#  b'\xbc\xec\x9a\xb0\xec\xa0\x80)\xec\x97\x90 \xec\xa0\x80\xec\x9e\xa5\xeb\x90'
#  b'\xa9\xeb\x8b\x88\xeb\x8b\xa4.</p>\n<div class="btn_area">\n<a href="https:/'
#  b'/help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view'
#  b'" data-clk="sug.cxlink" target="_blank">\xec\x9e\x90\xec\x84\xb8\xed\x9e'
#  b'\x88</a>\n</div>\n</div>\n<!-- [AU] _plus_layer_isnotloggedin '
#  b'\xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94'
#  b'\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<!-- [A'
#  b'U] style="display:none" \xec\xb6\x94\xea\xb0\x80\xed\x95\xb4\xec\xa3\xbc'
#  b'\xec\x84\xb8\xec\x9a\x94. -->\n<div class="_plus_layer_isnotloggedin" style'
#  b'="display:none">\n<p class="dsc"><em class="txt">\xeb\x8f\x99\xec'
#  b'\x9d\xbc\xed\x95\x9c \xec\x8b\x9c\xea\xb0\x84\xeb\x8c\x80/\xec\x97\xb0\xeb'
#  b'\xa0\xb9/\xeb\x82\xa8\xeb\x85\x80\xeb\xb3\x84</em> \xec\x82\xac\xec\x9a\xa9'
#  b'\xec\x9e\x90 \xea\xb7\xb8\xeb\xa3\xb9\xec\x9d\x98<br>\xea\xb4\x80'
#  b'\xec\x8b\xac\xec\x82\xac\xec\x97\x90 \xeb\xa7\x9e\xec\xb6\xb0 \xec\x9e\x90'
#  b'\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1\xec\x9d\x84 \xec\xa0\x9c'
#  b'\xea\xb3\xb5\xed\x95\xa9\xeb\x8b\x88\xeb\x8b\xa4.</p>\n<div class="btn_ar'
#  b'ea">\n<a href="https://nid.naver.com/nidlogin.login" class="btn btn_login'
#  b'" data-clk="sug.cxlogin">\xeb\xa1\x9c\xea\xb7\xb8\xec\x9d\xb8</a>\n<a href="'
#  b'https://help.naver.com/support/alias/search/word/word_16.naver" class="btn b'
#  b'tn_view" data-clk="sug.cxlink" target="_blank">\xec\x9e\x90\xec\x84'
#  b'\xb8\xed\x9e\x88</a>\n</div>\n</div>\n<!-- [AU] _plus_layer_close \xed'
#  b'\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea'
#  b'\xb0\x80\xed\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<a href="#" '
#  b'role="button" class="btn_close _plus_layer_close"><i class="imsc ico_close">'
#  b'\xec\xbb\xa8\xed\x85\x8d\xec\x8a\xa4\xed\x8a\xb8 \xec\x9e\x90'
#  b'\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1 \xeb\xa0\x88\xec\x9d\xb4\xec\x96\xb4 '
#  b'\xeb\x8b\xab\xea\xb8\xb0</i></a>\n</div>\n</div>\n</div>\n<div class="atcm'
#  b'p_footer">\n<span class="side_opt_area">\n<span class="opt_item"><a href="'
#  b'https://help.naver.com/alias/search/word/word_17.naver" data-clk="sug.help" '
#  b'target="_blank">\xeb\x8f\x84\xec\x9b\x80\xeb\xa7\x90</a></span>\n<span class'
#  b'="opt_item"><a href="https://help.naver.com/support/contents/contents.help?s'
#  b'erviceNo=605&categoryNo=18215" class="report" data-clk="sug.report" target="'
#  b'_blank">\xec\x8b\xa0\xea\xb3\xa0</a></span>\n</span>\n<span class="rside_opt'
#  b'_area">\n<span class="opt_item">\n<!-- [AU] _suggestOnOff \xed\x81\xb4\xeb'
#  b'\x9e\x98\xec\x8a\xa4\xeb\xa5\xbc \xec\xb6\x94\xea\xb0\x80\xed'
#  b'\x95\xb4\xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94. -->\n<a href="#" class="clos'
#  b'e _suggestOnOff">\xec\x9e\x90\xeb\x8f\x99\xec\x99\x84\xec\x84\xb1 \xeb\x81'
#  b'\x84\xea\xb8\xb0</a>\n</span>\n</span>\n</div>\n</div>\n</div>\n</div>\n</d'
#  b'iv>\n</div>\n\n</div>\n</div>\n\n<!--EMPTY-->\n<div id="gnb" role="navigati'
#  b'on">\n<div id="NM_FAVORITE" class="gnb_inner">\n<div class="group_nav">\n<u'
#  b'l class="list_nav type_fix">\n<li class="nav_item">\n<a href="https://mail'
#  b'.naver.com/" class="nav" data-clk="svc.mail"><i class="ico_mail"></i'
#  b'>\xeb\xa9\x94\xec\x9d\xbc</a>\n</li>\n<li class="nav_item"><a href="https://'
#  b'section.cafe.naver.com/" class="nav" data-clk="svc.cafe">\xec\xb9\xb4'
#  b'\xed\x8e\x98</a></li>\n<li class="nav_item"><a href="https://section.blog.'
#  b'naver.com/" class="nav" data-clk="svc.blog">\xeb\xb8\x94\xeb\xa1\x9c\xea\xb7'
#  b'\xb8</a></li>\n<li class="nav_item"><a href="https://kin.naver.com/" class="'
#  b'nav" data-clk="svc.kin">\xec\xa7\x80\xec\x8b\x9diN</a></li>\n<li class="nav'
#  b'_item"><a href="https://shopping.naver.com/" class="nav shop" data-clk="svc.'
#  b'shopping"><span class="blind">\xec\x87\xbc\xed\x95\x91</span></a></li>\n<li'
#  b' class="nav_item"><a href="https://shoppinglive.naver.com/home" class="nav s'
#  b'hoplive"\ndata-clk="svc.shoppinglive"><span class="blind">\xec\x87\xbc'
#  b'\xed\x95\x91LIVE</span></a></li>\n<li class="nav_item"><a href="https://or'
#  b'der.pay.naver.com/home" class="nav" data-clk="svc.pay">Pay</a></li>\n<li '
#  b'class="nav_item">\n<a href="https://tv.naver.com/" class="nav" data-clk="'
#  b'svc.tvcast"><i class="ico_tv"></i>TV</a>\n</li>\n</ul>\n<ul\nclass="list_nav'
#  b' NM_FAVORITE_LIST"\n>\n<li class="nav_item"><a href="https://dict.naver.co'
#  b'm/" class="nav" data-clk="svc.dic">\xec\x82\xac\xec\xa0\x84</a></li>\n<li c'
#  b'lass="nav_item"><a href="https://news.naver.com/" class="nav" data-clk="svc.'
#  b'news">\xeb\x89\xb4\xec\x8a\xa4</a></li>\n<li class="nav_item"><a href="http'
#  b's://finance.naver.com/" class="nav" data-clk="svc.stock">\xec\xa6\x9d'
#  b'\xea\xb6\x8c</a></li>\n<li class="nav_item"><a href="https://land.naver.co'
#  b'm/" class="nav" data-clk="svc.land">\xeb\xb6\x80\xeb\x8f\x99\xec\x82\xb0</a'
#  b'></li>\n<li class="nav_item"><a href="https://map.naver.com/" class="nav"'
#  b' data-clk="svc.map">\xec\xa7\x80\xeb\x8f\x84</a></li>\n<li class="nav_item"'
#  b'><a href="https://vibe.naver.com/?from&#x3D;naver_main&amp;utm_source&#x3D;n'
#  b'aver_main&amp;utm_medium&#x3D;naver_main_pcweb&amp;utm_campaign&#x3D;naver_m'
#  b'ain_redirect" class="nav" data-clk="svc.vibe">VIBE</a></li>\n<li class="n'
#  b'av_item"><a href="https://search.shopping.naver.com/book/home" class="nav" d'
#  b'ata-clk="svc.book">\xeb\x8f\x84\xec\x84\x9c</a></li>\n<li class="nav_item">'
#  b'<a href="https://comic.naver.com/" class="nav" data-clk="svc.webtoon'
#  b'">\xec\x9b\xb9\xed\x88\xb0</a></li>\n\n</ul>\n<ul class="list_nav type_em'
#  b'pty" style="display: none;"></ul>\n<a href="#" role="button" class="btn_m'
#  b'ore" data-clk="svc.more">\xeb\x8d\x94\xeb\xb3\xb4\xea\xb8\xb0</a>\n<div clas'
#  b's="ly_btn_area">\n<a href="more.html" class="btn NM_FAVORITE_ALL" data-cl'
#  b'k="map.svcmore">\xec\x84\x9c\xeb\xb9\x84\xec\x8a\xa4 \xec\xa0'
#  b'\x84\xec\xb2\xb4\xeb\xb3\xb4\xea\xb8\xb0</a>\n<a href="#" role="button" cla'
#  b'ss="btn btn_set" data-clk="map.edit">\xeb\xa9\x94\xeb\x89\xb4\xec'
#  b'\x84\xa4\xec\xa0\x95</a>\n<a href="#" role="button" class="btn btn_reset" da'
#  b'ta-clk="edt.reset">\xec\xb4\x88\xea\xb8\xb0\xed\x99\x94</a>\n<a href="#" rol'
#  b'e="button" class="btn btn_save" data-clk="edt.save">\xec\xa0\x80\xec'
#  b'\x9e\xa5</a>\n</div>\n</div>\n<div id="NM_WEATHER" class="group_weather">'
#  b'\n<div>\n<a data-clk="squ.weat" href="https://weather.naver.com/today/0953'
#  b'0102?cpName=KMA" class="weather_area ico_w01">\n<div class="current_box">'
#  b'\n<strong class="current" aria-label="\xed\x98\x84\xec\x9e\xac\xea'
#  b'\xb8\xb0\xec\x98\xa8">14.5\xc2\xb0</strong><strong class="state">'
#  b'\xeb\xa7\x91\xec\x9d\x8c</strong>\n</div>\n<div class="degree_box">\n<spa'
#  b'n class="min" aria-label="\xec\xb5\x9c\xec\xa0\x80\xea\xb8\xb0\xec\x98\xa8">'
#  b'6.0\xc2\xb0</span><span class="max" aria-label="\xec\xb5\x9c\xea\xb3\xa0'
#  b'\xea\xb8\xb0\xec\x98\xa8">15.0\xc2\xb0</span>\n</div>\n<span class="locati'
#  b'on">\xea\xb5\xac\xeb\xa1\x9c\xeb\x8f\x99</span>\n</a>\n</div>\n<div>\n<a da'
#  b'ta-clk="squ.dust" href="https://weather.naver.com/today/09530102?cpName=KMA"'
#  b' class="air_area">\n<ul class="list_air">\n<li class="air_item">\xeb\xaf'
#  b'\xb8\xec\x84\xb8<strong class="state state_normal">\xeb\xb3\xb4\xed\x86'
#  b'\xb5</strong></li>\n<li class="air_item">\xec\xb4\x88\xeb\xaf\xb8\xec'
#  b'\x84\xb8<strong class="state state_normal">\xeb\xb3\xb4\xed\x86\xb5</strong>'
#  b'</li>\n</ul>\n<span class="location">\xea\xb5\xac\xeb\xa1\x9c\xeb\x8f\x99'
#  b'</span>\n</a>\n</div>\n\n</div>\n</div>\n<div class="ly_service">\n<div cla'
#  b'ss="group_service NM_FAVORITE_ALL_LY"></div>\n<div class="group_service N'
#  b'M_FAVORITE_EDIT_LY" style="display: none;"></div>\n</div>\n</div>\n</div>\n '
#  b'<div id="container" role="main"> <div style="position:relative;width:1130px;'
#  b'margin:0 auto;z-index:11"> <div id="da_top"></div> <div id="da_expwide"></di'
#  b'v> </div> <div id="NM_INT_LEFT" class="column_left"> <div id="veta_top"> <di'
#  b'v id="veta_top_inner" style="height:135px"> </div> <span class="veta_bd_t"><'
#  b'/span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span'
#  b' class="veta_bd_r"></span> </div> <div id="newsstand" class="sc_newscast"> <'
#  b'h2 class="blind">\xeb\x89\xb4\xec\x8a\xa4\xec\x8a\xa4\xed\x83'
#  b'\xa0\xeb\x93\x9c</h2> <div id="NM_NEWSSTAND_HEADER" class="group_issue" data'
#  b'-clk-prefix="ncy"> <div class="issue_area"> <a class="link_media" href="http'
#  b's://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=0'
#  b'01&isYeonhapFlash=Y" data-clk="newsflash">\xec\x97\xb0\xed\x95\xa9'
#  b'\xeb\x89\xb4\xec\x8a\xa4</a> <div id="NM_ONELINE_ROLLING" class="list_issu'
#  b'e" data-nm-ui="rolling"> <div><a href="https://news.naver.com/main/list.nave'
#  b'r?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=001386644'
#  b'0" class="issue" data-clk="quickarticle">\xea\xb2\xbd\xea\xb8\xb0 '
#  b'\xec\xb9\xa8\xec\xb2\xb4\xec\x97\x90\xeb\x8f\x84 LG\xec\xa0\x84\xec\x9e'
#  b"\x90 1\xeb\xb6\x84\xea\xb8\xb0 '\xea\xb9\x9c\xec\xa7\x9d\xec\x8b\xa4"
#  b"\xec\xa0\x81'\xe2\x80\xa6\xec\x82\xbc\xec\x84\xb1\xec\xa0\x84"
#  b'\xec\x9e\x90\xeb\xb3\xb4\xeb\x8b\xa4 2\xeb\xb0\xb0 \xeb\xa7\x8e\xec\x95'
#  b'\x84</a></div>\n<div><a href="https://news.naver.com/main/list.naver?mode=LP'
#  b'OD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013866436" class='
#  b'"issue" data-clk="quickarticle">\xea\xb2\xbd\xec\xb0\xb0, \'\xec\xa0\x95'
#  b"\xec\x9e\x90\xea\xb5\x90 \xeb\xb6\x95\xea\xb4\xb4\xec\x82\xac\xea\xb3\xa0'"
# ...
#  b'                              </span>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t</'
#  b'div>\n\t\t\t\t\t</div>\n\t\t\t\t</a>\n\t\t\t\n\t\t</div>\n\t</div>\n</div'
#  b'>\n\n\n\n\n\n\t<div class="btn_more_wrap">\n\t\t<button type="button" clas'
#  b's="btn_more" data-clk-custom="tcc_bty.more" data-next-page="2"><i class="ico'
#  b'_more"></i>\xec\x83\x88\xeb\xa1\x9c\xec\x9a\xb4 \xea\xb8\x80 \xeb\x8d\x94'
#  b'\xeb\xb3\xb4\xea\xb8\xb0</button>\n\t</div>\n\n\n<div class="NM_THEME_META"'
#  b' style="display: none" data-panel-code="BEAUTY" data-parent-code=""></di'
#  b'v>\n\n\t</div>\n</div>\n </div> </div> <div id="NM_INT_RIGHT" class="colu'
#  b'mn_right"> <div class="column_fix_wrap"> <div id="da_brand"></div> \n'
#  b'\n\n\n\n\n<div id="account" class="sc_login">\n<h2 class="blind">Sign in</'
#  b'h2>\n<p class="login_msg">Connect with people</p>\n<a href="https://nid.na'
#  b'ver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com" class="lin'
#  b'k_login" data-clk="log_off.login"><i class="ico_naver"><span class="blind">N'
#  b'AVER</span></i>Sign in</a>\n<div class="sub_area">\n<div class="look_box">'
#  b'\n<a href="https://nid.naver.com/user/help.nhn?todo=idinquiry" class="lin'
#  b'k_look" data-clk="log_off.searchid">Forgot Username</a>\n<a href="https:/'
#  b'/nid.naver.com/nidreminder.form" class="link_look" data-clk="log_off.searchp'
#  b'ass">Password</a>\n</div>\n<a href="https://nid.naver.com/nidregister.form'
#  b'?url=https%3A%2F%2Fwww.naver.com" class="link_join" data-clk="log_off.regist'
#  b'ration">Sign up</a>\n</div>\n</div>\n\n\n\n <div id="timesquare" class="sc'
#  b'_timesquare"> <h2 class="blind">\xed\x83\x80\xec\x9e\x84\xec\x8a'
#  b'\xa4\xed\x80\x98\xec\x96\xb4</h2> <div class="card_wrap">\n<div class="car'
#  b'd_nav">\n<a href="#" role="button" class="btn_nav btn_prev" data-clk="squ'
#  b'.pre"><span class="blind">\xec\x9d\xb4\xec\xa0\x84</span></a>\n<a href="#" '
#  b'role="button" class="btn_nav btn_next" data-clk="squ.next"><span class="blin'
#  b'd">\xeb\x8b\xa4\xec\x9d\x8c</span></a>\n</div>\n<div id="NM_TS_ROLLING_WRAP"'
#  b' style="height: 100%;">\n<div>\n<a href="https://search.naver.com/search.n'
#  b'aver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%981'
#  b'9" class="card_news" data-clk="squ.line3"><i class="news_badge">'
#  b'\xec\x9d\xb4\xec\x8a\x88</i><span class="news">\xec\xbd\x94\xeb\xa1\x9c\xeb'
#  b'\x82\x98\xeb\xb0\x94\xec\x9d\xb4\xeb\x9f\xac\xec\x8a\xa4\xea\xb0'
#  b'\x90\xec\x97\xbc\xec\xa6\x9d-19 \xed\x98\x84\xed\x99\xa9</span></a>\n</d'
#  b'iv>\n<div>\n<a href="https://finance.naver.com/sise/sise_index.nhn?code=KO'
#  b'SPI" class="card_stock " data-clk="squ.kospi">\n<strong class="stock_titl'
#  b'e">\xec\xa6\x9d\xec\x8b\x9c</strong>\n<div class="stock_box">\n<em class="na'
#  b'me">\xec\xbd\x94\xec\x8a\xa4\xed\x94\xbc</em>\n<strong class="current">2,490'
#  b'.82</strong>\n<span class="rate rate_up"><span class="blind">'
#  b'\xec\x83\x81\xec\x8a\xb9</span>31.59 +1.28%</span>\n</div>\n</a>\n</div>\n'
#  b'<div>\n<a href="https://finance.naver.com/sise/sise_index.nhn?code=KOSDAQ'
#  b'" class="card_stock " data-clk="squ.kosdaq">\n<strong class="stock_title"'
#  b'>\xec\xa6\x9d\xec\x8b\x9c</strong>\n<div class="stock_box">\n<em class="name'
#  b'">\xec\xbd\x94\xec\x8a\xa4\xeb\x8b\xa5</em>\n<strong class="current">877.04<'
#  b'/strong>\n<span class="rate rate_up"><span class="blind">\xec\x83\x81\xec'
#  b'\x8a\xb9</span>11.46 +1.32%</span>\n</div>\n</a>\n</div>\n<div>\n<a href="h'
#  b'ttps://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_USD'
#  b'KRW" class="card_stock type_exchange" data-clk="squ.usd">\n<strong class='
#  b'"stock_title">\xed\x99\x98\xec\x9c\xa8</strong>\n<div class="stock_box">\n<e'
#  b'm class="name">USD</em>\n<strong class="current">1,318.60</strong>\n<span '
#  b'class="rate rate_down"><span class="blind">\xed\x95\x98\xeb\x9d\xbd</span>'
#  b'0.90 -0.07%</span>\n</div>\n</a>\n</div>\n</div>\n</div> <!-- EMPTY --> <'
#  b'/div> <div id="veta_branding"> <span class="blind"> <script id="veta_service'
#  b'_check"></script> </span> <div id="veta_branding_inner" style="width:350px;h'
#  b'eight:200px"> </div> <span class="veta_bd_t"></span> <span class="veta_bd_b"'
#  b'></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </d'
#  b'iv> <div id="shopcast" class="sc_shopcast"> <iframe id="shopcast_iframe" dat'
#  b'a-iframe-src="/shoppingbox/shoppingboxnew/main.nhn?mode=plusdeal&domain=N" t'
#  b'itle="\xec\x87\xbc\xed\x95\x91\xec\xba\x90\xec\x8a\xa4\xed\x8a\xb8" width'
#  b'="350" height="1809" marginheight="0" marginwidth="0" scrolling="no" framebo'
#  b'rder="0"></iframe> </div> </div> </div> <a id="NM_scroll_top_btn" href="#wra'
#  b'p" class="content_top"><span class="blind">TOP</span></a> <button id="NM_dar'
#  b'kmode_btn" type="button" role="button" class="btn_theme" aria-pressed="false'
#  b'"  > <span class="blind">\xeb\x9d\xbc\xec\x9d\xb4\xed\x8a\xb8 \xeb'
#  b'\xaa\xa8\xeb\x93\x9c\xeb\xa1\x9c \xeb\xb3\xb4\xea\xb8\xb0</span> </button>'
#  b' </div> <div id="footer" role="contentinfo"> <div class="footer_inner"> <div'
#  b' id="NM-FOOTER-AD" class="banner_area"> <div class="da_box_wrap"> <div id="d'
#  b'a_public_left"> </div> <div id="da_public_right"> </div> <div id="veta_time2'
#  b'"> </div> </div> </div> <div class="notice_area" data-clk-prefix="ntc"> <div'
#  b' class="notice_box"> <h3 class="title"><a href="https://www.naver.com/NOTICE'
#  b'">\xea\xb3\xb5\xec\xa7\x80\xec\x82\xac\xed\x95\xad</a> </h3> <!-- EMPTY --> '
#  b'</div> <a href="more.html" class="link_all" data-clk="svcmap">\xec\x84'
#  b'\x9c\xeb\xb9\x84\xec\x8a\xa4 \xec\xa0\x84\xec\xb2\xb4\xeb\xb3'
#  b'\xb4\xea\xb8\xb0</a> </div> <div class="aside_area"> <div class="partner_box'
#  b'_wrap"> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Cr'
#  b'eators</h3> <a href="https://www.navercorp.com/service/creators" class="link'
#  b'_partner" data-clk="creator">\xed\x81\xac\xeb\xa6\xac\xec\x97\x90\xec\x9d'
#  b'\xb4\xed\x84\xb0</a> <a href="https://www.navercorp.com/service/business" cl'
#  b'ass="link_partner" data-clk="smbusiness">\xec\x8a\xa4\xeb\xaa\xb0\xeb'
#  b'\xb9\x84\xec\xa6\x88\xeb\x8b\x88\xec\x8a\xa4</a> </div> <div class="partn'
#  b'er_box" data-clk-prefix="crt"> <h3 class="title">Partners</h3> <a href="http'
#  b's://campaign.naver.com/smefullcare/online/" class="link_partner" data-clk="s'
#  b'me">SME \xed\x92\x80\xec\xbc\x80\xec\x96\xb4 \xec\x8b\x9c\xec\x8a\xa4'
#  b'\xed\x85\x9c</a> <a href="https://business.naver.com/service.html" class='
#  b'"link_partner" data-clk="service">\xeb\xb9\x84\xec\xa6\x88\xeb\x8b\x88\xec'
#  b'\x8a\xa4 \xc2\xb7 \xea\xb4\x91\xea\xb3\xa0</a> <a href="https://sell.store'
#  b'farm.naver.com/#/home/about" class="link_partner" data-clk="store">\xec'
#  b'\x8a\xa4\xed\x86\xa0\xec\x96\xb4 \xea\xb0\x9c\xec\x84\xa4</a> <a href="htt'
#  b'ps://smartplace.naver.com" class="link_partner" data-clk="place"'
#  b'>\xec\xa7\x80\xec\x97\xad\xec\x97\x85\xec\xb2\xb4 \xeb\x93\xb1\xeb\xa1\x9d'
#  b'</a> <a href="https://expert.naver.com/expert/introduction?tab=guide#join" c'
#  b'lass="link_partner" data-clk="expert">\xec\x97\x91\xec\x8a\xa4'
#  b'\xed\x8d\xbc\xed\x8a\xb8 \xeb\x93\xb1\xeb\xa1\x9d</a> </div> <div class="par'
#  b'tner_box" data-clk-prefix="crt"> <h3 class="title">Developers</h3> <a href="'
#  b'https://developers.naver.com" class="link_partner" data-clk="center"'
#  b'>\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xea\xb0\x9c\xeb\xb0\x9c\xec\x9e\x90'
#  b' \xec\x84\xbc\xed\x84\xb0</a> <a href="https://developers.naver.com/docs/c'
#  b'ommon/openapiguide/#/apilist.md" class="link_partner" data-clk="openapi"'
#  b'>\xec\x98\xa4\xed\x94\x88 API</a> <a href="https://naver.github.io" class='
#  b'"link_partner" data-clk="opensource">\xec\x98\xa4\xed\x94\x88\xec'
#  b'\x86\x8c\xec\x8a\xa4</a> <a href="https://d2.naver.com" class="link_partner'
#  b'" data-clk="d2">\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 D2</a> <a href="http:/'
#  b'/d2startup.com" class="link_partner" data-clk="naverD2SF">\xeb\x84'
#  b'\xa4\xec\x9d\xb4\xeb\xb2\x84 D2SF</a> <a href="https://www.naverlabs.com"'
#  b' class="link_partner" data-clk="labs">\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 '
#  b'\xeb\x9e\xa9\xec\x8a\xa4</a> </div> </div> <div class="service_box_wrap"> '
#  b'<div class="service_box" data-clk-prefix="wbd"> <a href="http://whale.naver.'
#  b'com/" class="service_logo" data-clk="bt"> <img src="...'
#  b'BORw0KGgoAAAANSUhEUgAAAGAAAABgCAMAAADVRocKAAAC91BMVEUAAACE1dAbf6jE1Nq/z9e82d'
#  b'rQ3OG7ytOzws+6x9QNs7MeLpQSx60QrLAfL50gMakTxKyzwc8fMacSr6yywc8fMKIdLYzJ1d4Krr'
#  b'W6ydMJrrUbr6QgMKW2xNEcr6W7ydUfL5cIr7XBztgMtbMeL50fMaQQzrI0tK4cLIQUvqsVvqofMK'
#  b'LL0eGzxM+4xtIZuKcJr7XCyNt0xsILsLW1w9AdLYZwvL8gMaoeLY6CzMceLYyxz9fI1d0JwLMeLY'
#  b'4KrbXFzeAgMqvN2OEIrLUGsrVIurMfLpAcLIIIsbVWs7MeLpXIzt0UvakgMqwfL5x4wcEJsLYfMa'
#  b'gWt6k6qqoil6DV2+UdK4EeMoEfLpOzws4/s7YgMacXvqoC27QcK38B17TE1dobKW0bKnID0bTP3O'
#  b'ACzrQcKngcLIMbKXAD07QeLYfi6uzY4+YfLpDN2+DK2d0cK3zU4eTS3+IFzLQeL5ccKnXk7O7G19'
#  b'wgMJ3R3uHa5ejL2t7c5unI2Nzg6esBxrMfMKPp7vEeLYrr8fMNr7X2+PkeLYzt8vQE2LTx9fYfLp'
#  b'Pz9/gHyLMOsrUHr7UCybQLs7YKu7UIuLUFvLQGwbUIxbQGw7QcKnTZ5OfV4uUJv67e5+rd5+rl7e'
#  b'8Ju6z3+vvm7vDp8PHs8vPw9fbv9PUgMaj6/PwgMqwJs6kNw7AFubULtrUGtbUJvrQEv7QAwq8Mrq'
#  b'YKuKsKtqn+/v4Osaf7/P0K1rMHq6UeqKQNqKQhNoIgSH0Vvqoie5MhWIdV3cAcsaYhhZoglJkdLX'
#  b'nJ7+ia5tU61rgp1rceoKIhb4whZYgcM3fj9vJw3sdJx7xtd6sXt6hCT5AvPpAfPYQbKIMcJ34fP3'
#  b'q+8uSy49ux0tWd2NKYzM+A48yE08t6xchdv8FP0b1zfbcSpKIgToEbJ3nE5OG12Nmn19WM5tGKk8'
#  b'ehqMZlxcJJuLwgtLcbvbYc2bUTtaknNpA1Q4bZ7uuzuNuP3M9p0cNfbLUKtq5IVqk8Sp8jZpxaZZ'
#  b'rUCA9eAAAAXXRSTlMABAj99BcO6IpfLhj9hPLp5ryyq6ZzXDnd2cuYkHtzbFFOQj0yJv76+ebc29'
#  b'fXx8TCuJuVlIqHgX5gPS0kEvn49/f08O3t6+fj2tLR0MzGeGNfWvbz7sXBpYN4PB4CDkIdAAAFcU'
#  b'lEQVRo3q3TdVwTYRjA8eeI0SKgYnd3d3d362tgO7u7Y4rd3d2K4pwwQkAQJUSxu7vbPzwYg9vufe'
#  b'+eO/neP9vtPr/n7t53gFMobxXPVu719pu4t/LM2a4gBwioeGZP9/0U9TyrFEyHepUSeyW45+wB/8'
#  b'GmXetZskpkdlGbz+w+CyVDThdV+QyT0FSMyFtikiIZMnOggIvnOMWaFwS0LBkkQj/q/mL8UpVDvv'
#  b'2ui6V89XvF+qm1C2rnNx8u6ferq8zfGlcHWdUbD/8PtbPI7p7aC5R49Mn6TFWZ5Z2jzKNPolOVJP'
#  b'tD04HEhLxFh6YH5lsqWHQQ1dVBCjFW2qUJo+8Xq3BAUeputenci27Qo6u9FGpC+8dV6pUODAZDQk'
#  b'KCwdAFRNz+s2wMiYwbQkwi7oWVBCvOHUep9yQkTkfMIsIv+/HygKVigaPoYuMFX+InGEQXJIS4kj'
#  b'RBN/b5JZutAaHcxDhQ3gVD7AWrU0a9TpgPO5OqnMUOciWJA9O8jh+IYwwmAhE39gnMrwFpchByQX'
#  b'Cjn/kvCOf1ROil7z4LgnWuVZiQ8UpFh/gTgYs3tlvzFj4AiVbYN7oSoaDL20VaQAou6drE9UpcCC'
#  b'UWruyeL+ZbM3UL8Yw+YrHD4n2ozgdY9X3n05g3UnHCC6R0Xvv9pfaj/ImFoN3zqbQcJOlJkugpof'
#  b'WfafnoSGIp4rIvg5N5iXn+0aIS7vUQ/zBfFtMyFyPJogajXOpHrIQvYprNJf0JiEkAJu8TQqwF7V'
#  b'nE5mTaQyaX5PvRwUQkbLeEpH1UhqRw9ZHrP3ElInf3SOkEABmJWWhfaVG9iciHywulzNWAjY6kui'
#  b'SV9wklFOELpeWHAsINZ2T3+d1JcXHrLmkVITcRGMJ8hsDehCZ8rozSkINYCKTmn8QRQn8AuQElwY'
#  b'tYCj4vyieG6gjdy51y6kMZYkUXmmj58kP9CcOHL7PlaKElEdEFR5031wPjCNvd2fKgOKHqF6CP1A'
#  b'eI7j1k+PA/aSfDdsiDjESBgDm8SJIiaCuCsgH6a7xAkuLmBASFA67zzAMuanEDdAoUHvX06dNgnc'
#  b'ldLQYU763Ex6hLkebPz7TaCfIHtOyt0kMtCpRROyAc1R8GXvy1Q1Qc/htmYNQFtyHqXEH1N2eD9i'
#  b'oH3NyM4gHO/VSJ2IKTC7ixqgZ8m4bjDVBMTb/waFx/IwfgNUCFK1NwHACgvZoBN5EDMgGAzRJWZS'
#  b'yz/3ADkjfwGo1V7PYwnPoc8MovZ2Dll18cjRzgAUnsDy5hYE24NwwpPyRrNJNuOcOSZxtx7MCk2k'
#  b'G6JQzfRyM5Qooix2lmsjxH9qdqIEX5TTRrGR6OQcoEZlwRSp/5BC/GjEYdI+whVfltYgfX0sXgH0'
#  b'CgiKh/fB3D7ck4thoQqHbS2kFGP2YyUi6w0OyUpW1rGG73x3HgwIJ98AGhU0cZ/Rhkf2oNsNLGYs'
#  b'C2YwwvkAMcQaTZ6TQfjzK8QfazcSDCdTiRajXD++cjUOzsgaKG3tz/uZLhHq4/PT9QVTt3NtmB1Q'
#  b'wxI3EDnIChzeNzvLMrGd7fmoriCEyVH/P9Qyx3cP2KAJITDq9iuD8SxREkdT/C6j+Yjup3A0nOTQ'
#  b'8zPJiIyds6gaQCDY8wvJk4HcHOGyS1XbqC4f50jNL2IMWmwlKGd3cmItjmknn92VcwvL2F6ZeqKX'
#  b'37bszbv98HwU5mdfNlncfw4FYf3kSpg887aqQ3T1lW/u2dPnLk8/nKLmMoW9nDVjZfyomTzjdl1B'
#  b'tWcAYA+zylpGY4ONYEOc5u2evMs5a1QoHU+9I4ZXKwpcU98tgDDufc1s0re9YGdZYta5A1u5dbvl'
#  b'pgReOdp6JHNgc7fpCtnUO20ply5UfG/wEFXaai/lOVTwAAAABJRU5ErkJggg==" alt='
#  b'"\xec\x9b\xa8\xec\x9d\xbc" width="48" height="48"> </a> <div class="servic'
#  b'e_info"> <strong class="title">\xec\x9b\xa8\xec\x9d\xbc \xeb\xb8'
#  b'\x8c\xeb\x9d\xbc\xec\x9a\xb0\xec\xa0\x80</strong> <a href="http://whale.na'
#  b'ver.com/" class="dsc" data-clk="bt">\xeb\x8b\xa4\xec\x9a\xb4\xeb\xb0'
#  b'\x9b\xea\xb8\xb0</a> </div> </div> <div class="service_box" data-clk-prefix='
#  b'"prj"> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_'
#  b'hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class'
#  b'="service_logo" data-clk="link"> <img src="...'
#  b'AAAANSUhEUgAAAF4AAABkCAMAAAA47XeXAAAAgVBMVEUAAADN5PdGm99Gm99Gm99Gm99Gm95Gm99'
#  b'Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gm99Gmt9Gm99Gm99Gm99'
#  b'Gm95Gm99Gm99Gm95Gm99Hm99Gm99Gm9/////3+/5cp+LO5PfR5/fO5fdcp+P7/f/zv5GhAAAAInR'
#  b'STlMA/v7vH9u5qJNgGwb6l8a9uqF9WFUyLxYMCtbVmLCwe4OCj8gzEgAAA0NJREFUaN7NmmFz4iA'
#  b'QhkkwMTHGWrWtWvWuq8mF+/8/8Ey2nb0OhSwQZnw+MHQ7pbjAy2s2gsuiLPJMLpcyy4tyISZltnm'
#  b'Hbxw3MzEVr/MUNNL5q5iCt2ccXCN9fhPB7CQYkTsRRlWDlboSAexzGCHfC28OKxhldfDOzBMwePL'
#  b'NTw0sauHFFphshQcLCUwkaQRfXYBPSkrEUBdv3jezcXXhw1ciUhc+fCUidQlH7qzqEk5d2dQlnHx'
#  b'vU5dwVgdXdSGclaiGyamt6hLO1qIu4ZASzcFE092SBprk1jagulvXAAw/qb5N7m176xQYmOPoLym'
#  b'YaK/X65/PNhlagE6LGUhfRM8FjNzuf/73//bHmInzoJEpjMyeWpp9RzGz/PT6+QvMNO2Q+67PPeY'
#  b'ZY5h7jDVg5OM+/BGikd13JfDAj/Ad1WLMyEyUwKPT00ypN1GKAljQJtFiFgqRe86eYhbWIvPPPR5'
#  b'd+9pKiIgUwKNJdHXBvW9jyRye1EWLWYfnJcd141Byspizz7gbUyWDuqiW0v15D9g3ZgF86JwyKUg'
#  b'UHJaATUmS5rsEdkkTZLjZS8Alw+skFr8Nl6H6uosShaKOp3Zo+/jgFTDe+wcSfv0yFGfQaLX7tDO'
#  b'0reXOPRuMCG4Q11Y3IiYblWgzS7R+h31qdRtlGB7zikeUckz+AB3a8FuMqD7Cd2nhUHLOEIkLubQ'
#  b'IkEuLxIdwEwUy3HyXxsbgPMJcGuGox+TSIugxuTQ+KHIaAS5N92eIIuMT5tJoPfHy5q9yKoXLelL'
#  b'uKRri0mjMQdhwTPw6Sv8pzKXhFyhNilEwkSCXRrnAnaPnJdyl0UrqXircpeHVglnv+62K4NJo3lF'
#  b'cGmWd79KO7OQoXAE8XNO6tIQGxj7fpfHTwk8RubQLWEGvgTNGKzj01fixunCMCCYcvSSlaFwUyKV'
#  b'x86J3bczpUR3zimq1LqdosAUbJF54ar+uk5Gju436mPTk8ZAXFdO93HRYTesUVgf3B+y0XdxLfdV'
#  b'putmfKp/iBtNjyl3c0kzUwtJIWewIPvAL9LOyWLsV9WAps3VRzh6hJBm3oOqsRKfHLGYzS/GP+iL'
#  b'BuBKdqkd+iWPkFZTHf4Em4us/uhI5qss/6zK5u8+AXpwAAAAASUVORK5CYII=" alt="'
#  b'\xea\xbd\x83" width="47" height="50"> </a> <div class="service_info"> <st'
#  b'rong class="title">\xed\x94\x84\xeb\xa1\x9c\xec\xa0\x9d\xed\x8a\xb8 '
#  b'\xea\xbd\x83</strong> <a href="https://search.naver.com/search.naver?wher'
#  b'e=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%'
#  b'B8%EA%BD%83" class="dsc" data-clk="link">\xeb\xb0\x94\xeb\xa1\x9c\xea'
#  b'\xb0\x80\xea\xb8\xb0</a> </div> </div> </div> </div> <div class="corp_area"'
#  b' data-clk-prefix="plc"> <h3 class="blind">\xeb\x84\xa4\xec\x9d\xb4'
#  b'\xeb\xb2\x84 \xec\xa0\x95\xec\xb1\x85 \xeb\xb0\x8f \xec\x95\xbd\xea\xb4'
#  b'\x80</h3> <ul class="list_corp"> <li class="corp_item"><a href="https://www'
#  b'.navercorp.com" data-clk="intronhn">\xed\x9a\x8c\xec\x82\xac\xec\x86'
#  b'\x8c\xea\xb0\x9c</a></li> <li class="corp_item"><a href="https://recruit.nav'
#  b'ercorp.com/" data-clk="recruit">\xec\x9d\xb8\xec\x9e\xac\xec\xb1'
#  b'\x84\xec\x9a\xa9</a></li> <li class="corp_item"><a href="https://www.naverco'
#  b'rp.com/naver/proposalGuide" data-clk="contact">\xec\xa0\x9c\xed\x9c'
#  b'\xb4\xec\xa0\x9c\xec\x95\x88</a></li> <li class="corp_item"><a href="/pol'
#  b'icy/service.html" data-clk="service">\xec\x9d\xb4\xec\x9a\xa9\xec'
#  b'\x95\xbd\xea\xb4\x80</a></li> <li class="corp_item"><a href="/policy/privac'
#  b'y.html" data-clk="privacy"><strong>\xea\xb0\x9c\xec\x9d\xb8\xec\xa0\x95'
#  b'\xeb\xb3\xb4\xec\xb2\x98\xeb\xa6\xac\xeb\xb0\xa9\xec\xb9\xa8</strong></a>'
#  b'</li> <li class="corp_item"><a href="/policy/youthpolicy.html" data-clk="you'
#  b'th">\xec\xb2\xad\xec\x86\x8c\xeb\x85\x84\xeb\xb3\xb4\xed\x98\xb8\xec'
#  b'\xa0\x95\xec\xb1\x85</a></li> <li class="corp_item"><a href="https://policy'
#  b'.naver.com/policy/service_group.html" data-clk="policy">\xeb\x84\xa4\xec'
#  b'\x9d\xb4\xeb\xb2\x84 \xec\xa0\x95\xec\xb1\x85</a></li> <li class="corp_it'
#  b'em"><a href="https://help.naver.com/" data-clk="helpcenter">\xea\xb3\xa0\xea'
#  b'\xb0\x9d\xec\x84\xbc\xed\x84\xb0</a></li> </ul> <address class="addr"><a hre'
#  b'f="https://www.navercorp.com" target="_blank" data-clk="nhn">\xe2\x93\x92'
#  b' NAVER Corp.</a></address> </div> </div> </div> </div> <div id="adscript" st'
#  b'yle="display:none"></div> </body> </html>\n')

# %%
# !pip3 install pprint
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement pprint (from versions: none)
# ERROR: No matching distribution found for pprint
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
