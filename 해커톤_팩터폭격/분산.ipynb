# %%
import pandas as pd

# %%
kospi = pd.read_csv("./kospi(최종).csv")
kospi
# Out:
#          회사명    종목코드  회계년도        종가    ROE       상장주식수          시가총액
# 0      DB하이텍     990  2014    4615.0 -47.32  44367832.0  2.047575e+11  \
# 1      DB하이텍     990  2015   14300.0  67.63  44367832.0  6.344600e+11
# 2      DB하이텍     990  2016   15900.0  29.65  44367832.0  7.054485e+11
# 3      DB하이텍     990  2017   12000.0  27.62  44367832.0  5.324140e+11
# 4      DB하이텍     990  2018   10850.0  17.12  44398588.0  4.817247e+11
# ...      ...     ...   ...       ...    ...         ...           ...
# 1334  효성첨단소재  298050  2021  596000.0  41.51   4479948.0  2.670049e+12
# 1335  효성첨단소재  298050  2022  333500.0  19.11   4479948.0  1.494063e+12
# 1336   효성티앤씨  298020  2020  211000.0  25.10   4327682.0  9.131409e+11
# 1337   효성티앤씨  298020  2021  521000.0  76.22   4327682.0  2.254722e+12
# 1338   효성티앤씨  298020  2022  350000.0   0.88   4327682.0  1.514689e+12
#
#             수익률     PER    PBR     PCR    PSR        ROA       NEW        EY
# ...

# %%
variance = kospi['수익률'].var()
print(variance)
# Out:
# 48.06153766843676
