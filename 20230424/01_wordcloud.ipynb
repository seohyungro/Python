# %% [markdown]
# # 워드클라우드

# %% [markdown]
# 1. 라이브러리 이름은 wordcloud

# %%
# !pip3 install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-macosx_10_9_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: pillow in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from wordcloud) (1.24.2)
# Requirement already satisfied: matplotlib in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: cycler>=0.10 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# WARNING: You are using pip version 21.2.4; however, version 23.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip3 install konlpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 5.6 MB/s eta 0:00:011
# Requirement already satisfied: lxml>=4.1.0 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from konlpy) (4.9.2)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp39-cp39-macosx_10_9_x86_64.whl (381 kB)
#      |████████████████████████████████| 381 kB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.6 in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from konlpy) (1.24.2)
# Requirement already satisfied: packaging in /Users/noseohyeong/Library/Python/3.9/lib/python/site-packages (from JPype1>=0.7.0->konlpy) (23.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0
# WARNING: You are using pip version 21.2.4; however, version 23.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from wordcloud import WordCloud
from konlpy.tag import Okt
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
text=open('hiphop.txt',encoding="euc-kr").read()

# %%
okt=Okt()

# Okt 함수를 이용하여 내용의 형태를 분석 -> 한국어를 단어별로 쪼갬
nouns = okt.nouns(text)

# %%
nouns
# Out:
# ['보고',
#  '말',
#  '더',
#  '보고',
#  '너희',
#  '사진',
#  '보고',
#  '보고',
#  '시간',
#  '나',
#  '우리',
#  '젠',
#  '얼굴',
#  '한번',
#  '것',
#  '조차',
#  '우리',
#  '온통',
#  '겨울',
#  '뿐',
#  '겨울',
#  '마음',
#  '시간',
#  '홀로',
#  '설국열차',
#  '니',
#  '손',
#  '잡고',
#  '지구',
#  '반대편',
#  '겨울',
#  '끝내',
#  '그리움',
#  '얼마나',
#  '눈',
#  '그',
#  '봄날',
#  '허공',
#  '도',
#  '먼지',
#  '먼지',
#  '눈',
#  '나라',
#  '조금',
#  '더',
#  '네',
#  '수',
#  '눈꽃',
#  '또',
#  '보고',
#  '보고',
#  '보고',
#  '보고',
#  '얼마나',
#  '또',
#  '몇',
#  '밤',
#  '더',
#  '널',
#  '널',
#  '겨울',
#  '끝',
#  '지나',
#  '다시',
#  '봄날',
#  '때',
#  '꽃',
#  '때',
#  '곳',
#  '좀',
#  '더',
#  '니',
#  '니',
#  '내',
#  '내',
#  '이',
#  '순간',
#  '시간',
#  '우리',
#  '거지',
#  '뭐',
#  '모두',
#  '거지',
#  '뭐',
#  '니',
#  '넌',
#  '단',
#  '하루',
#  '너',
#  '적',
#  '난',
#  '보고',
#  '너',
#  '그게',
#  '널',
#  '덜',
#  '널',
#  '연기',
#  '연기',
#  '말',
#  '해도',
#  '사실',
#  '난',
#  '널',
#  '눈꽃',
#  '또',
#  '보고',
#  '보고',
#  '보고',
#  '보고',
#  '얼마나',
#  '또',
#  '몇',
#  '밤',
#  '더',
#  '널',
#  '널',
#  '아침',
#  '다시',
#  '어둠',
#  '계절',
#  '순',
#  '벚꽃',
#  '피나',
#  '이',
#  '겨울',
#  '끝',
#  '보고',
#  '보고',
#  '보고',
#  '보고',
#  '조금',
#  '며칠',
#  '밤',
#  '더',
#  '겨울',
#  '끝',
#  '지나',
#  '다시',
#  '봄날',
#  '때',
#  '꽃',
#  '때',
#  '곳',
#  '좀',
#  '더',
#  '일단',
#  '시작',
#  '제일',
#  '걸',
#  '부탁',
#  '바텐더',
#  '연속',
#  '나니',
#  '모두',
#  '침',
#  '고여',
#  '널',
#  '처음',
#  '난',
#  '말',
#  '넌',
#  '저기',
#  '여자',
#  '달리',
#  '틱틱',
#  '거려',
#  '분위기',
#  '줄기',
#  '빛',
#  '정도',
#  '마치',
#  '사춘기',
#  '너',
#  '눈빛',
#  '입술',
#  '바짝',
#  '마르지',
#  '만',
#  '나',
#  '이',
#  '밤',
#  '가기',
#  '전',
#  '난',
#  '널',
#  '내',
#  '품',
#  '안',
#  '고민',
#  '고민',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '마르고',
#  '난',
#  '여러',
#  '명의',
#  '포로',
#  '곳',
#  '빠삐용',
#  '나',
#  '지긋지긋',
#  '희끗희끗',
#  '머리',
#  '나',
#  '아치',
#  '이제',
#  '끝',
#  '바람둥이',
#  '가닥',
#  '나라',
#  '남자',
#  '네',
#  '몰래',
#  '난',
#  '원래',
#  '모든',
#  '싫증',
#  '벌레',
#  '나이',
#  '사랑',
#  '단',
#  '도',
#  '뒤',
#  '처리',
#  '피',
#  '눈물',
#  '로맨스',
#  '장단',
#  '너',
#  '오락가락',
#  '멜로디',
#  '다른',
#  '알토',
#  '소프라노',
#  '어차피',
#  '우리',
#  '말',
#  '꿈',
#  '너',
#  '눈빛',
#  '입술',
#  '바짝',
#  '마르지',
#  '만',
#  '나',
#  '이',
#  '밤',
#  '가기',
#  '전',
#  '난',
#  '널',
#  '내',
#  '품',
#  '안',
#  '고민',
#  '고민',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '차',
#  '타고',
#  '술',
#  '취했으',
#  '눈',
#  '좀',
#  '잠깐',
#  '어디',
#  '난',
#  '손',
#  '잡고',
#  '자',
#  '속',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '에',
#  '게',
#  '소리',
#  '때',
#  '분명',
#  '속도',
#  '속',
#  '목소리',
#  '날',
#  '땐',
#  '분명',
#  '이',
#  '상처',
#  '듯',
#  '애',
#  '눈물',
#  '사탕',
#  '막',
#  '자기',
#  '슬픔',
#  '쇠똥구리',
#  '면서',
#  '난',
#  '왜',
#  '널',
#  '안지',
#  '그날',
#  '결판',
#  '순간',
#  '터널',
#  '너',
#  '눈가',
#  '그',
#  '생각',
#  '자꾸',
#  '내',
#  '맘',
#  '저기',
#  '좀',
#  '그',
#  '사람',
#  '나',
#  '곳',
#  '두',
#  '다리',
#  '어딘가',
#  '내',
#  '집',
#  '밤하늘',
#  '그대',
#  '알',
#  '그대',
#  '마음',
#  '시간',
#  '지나',
#  '사랑',
#  '이면',
#  '사랑',
#  '이면',
#  '너',
#  '집',
#  '서로',
#  '심술',
#  '자존심',
#  '그',
#  '정도',
#  '거리',
#  '우린',
#  '맘',
#  '툭',
#  '말',
#  '진심',
#  '항상',
#  '박자',
#  '그',
#  '발짝',
#  '이',
#  '꼴',
#  '저',
#  '꼴',
#  '끝',
#  '지네',
#  '평',
#  '아파트',
#  '겨우',
#  '원룸',
#  '못',
#  '처음',
#  '너',
#  '후',
#  '싹',
#  '줄',
#  '더',
#  '뒷모습',
#  '몰래',
#  '넌',
#  '줄',
#  '친구',
#  '년',
#  '술자리',
#  '욕',
#  '속',
#  '뭘',
#  '니',
#  '편',
#  '머리',
#  '집',
#  '가야',
#  '지갑',
#  '어디',
#  '밤하늘',
#  '그대',
#  '알',
#  '그대',
#  '마음',
#  '시간',
#  '지나',
#  '사랑',
#  '이면',
#  '사랑',
#  '이면',
#  '너',
#  '집',
#  '아저씨',
#  '사실',
#  '나',
#  '곳',
#  '그',
#  '사람',
#  '내',
#  '마음',
#  '둘',
#  '곳',
#  '가야',
#  '다시',
#  '볼',
#  '수',
#  '우리',
#  '집',
#  '못',
#  '아저씨',
#  '그',
#  '사람',
#  '그',
#  '사람',
#  '나',
#  '곳',
#  '가야',
#  '다시',
#  '볼',
#  '수',
#  '우리',
#  '집',
#  '못',
#  '밤하늘',
#  '그대',
#  '알',
#  '그대',
#  '마음',
#  '시간',
#  '지나',
#  '사랑',
#  '이면',
#  '사랑',
#  '이면',
#  '너',
#  '집',
#  '저',
#  '골목길',
#  '자주',
#  '길',
#  '너',
#  '마중',
#  '버스',
#  '정류장',
#  '미용실',
#  '지나',
#  '오르막',
#  '길',
#  '불',
#  '너',
#  '집',
#  '앞',
#  '난',
#  '우연',
#  '만화',
#  '기적',
#  '그',
#  '사람',
#  '지금',
#  '어디',
#  '우리',
#  '집',
#  '못',
#  '사랑',
#  '이면',
#  '사랑',
#  '이면',
#  '그땐',
#  '울',
#  '오늘',
#  '두',
#  '잔',
#  '반',
#  '뼘',
#  '위로',
#  '한숨',
#  '나니',
#  '기분',
#  '좀',
#  '요즘',
#  '게',
#  '봄',
#  '가을',
#  '건',
#  '내',
#  '나로',
#  '내',
#  '곁',
#  '내',
#  '무뎌졌던',
#  '년',
#  '두',
#  '번',
#  '내',
#  '눈물',
#  '길',
#  '그',
#  '노래',
#  '내',
#  '마음',
#  '때',
#  '조금',
#  '이유',
#  '스트레스',
#  '버티고',
#  '증발',
#  '꽉',
#  '쥐',
#  '대가',
#  '때',
#  '그냥',
#  '어도',
#  '더',
#  '슬픔',
#  '때',
#  '눈물',
#  '쯤',
#  '내',
#  '엄지',
#  '네',
#  '눈',
#  '밑',
#  '줄',
#  '거지',
#  '뭐',
#  '라며',
#  '내',
#  '주병',
#  '때',
#  '마흔',
#  '너',
#  '손',
#  '담배',
#  '구름',
#  '우릴',
#  '것',
#  '기침',
#  '웃음',
#  '잠시',
#  '혼자',
#  '것',
#  '우린',
#  '서로',
#  '친구',
#  '때론',
#  '우울',
#  '불운',
#  '날',
#  '나태',
#  '그물',
#  '자기',
#  '길',
#  '나',
#  '선',
#  '것',
#  '물음',
#  '머릿속',
#  '계속',
#  '현실',
#  '겉',
#  '때론',
#  '내',
#  '유령',
#  '애',
#  '고독',
#  '무덤',
#  '애',
#  '넌',
#  '그',
#  '속',
#  '날',
#  '이',
#  '노래',
#  '후렴',
#  '애',
#  '때',
#  '그냥',
#  '어도',
#  '더',
#  '슬픔',
#  '때',
#  '눈물',
#  '쯤',
#  '내',
#  '엄지',
#  '네',
#  '눈',
#  '밑',
#  '줄',
#  '혼자',
#  '오늘',
#  '누군가',
#  '혼자',
#  '집',
#  '역시',
#  '외로워',
#  '를',
#  '잠',
#  '수',
#  '평점',
#  '속',
#  '날',
#  '채점',
#  '몇몇',
#  '하루',
#  '문턱',
#  '수',
#  '내',
#  '나로',
#  '수',
#  '가끔',
#  '왜',
#  '사나',
#  '도대체',
#  '난',
#  '어디',
#  '가나',
#  '가면',
#  '이제',
#  '가명',
#  '이',
#  '내',
#  '갈피',
#  '못',
#  '잡고',
#  '때',
#  '누군가',
#  '건',
#  '계산',
#  '수',
#  '가치',
#  '거짓',
#  '껍질',
#  '세상',
#  '우린',
#  '서로',
#  '장난',
#  '판단',
#  '힘',
#  '잠깐',
#  '눈',
#  '좀',
#  '얼마나',
#  '고',
#  '바람',
#  '이',
#  '비',
#  '때',
#  '때',
#  '그냥',
#  '어도',
#  '슬픔',
#  '때',
#  '눈물',
#  '쯤',
#  '내',
#  '엄지',
#  '네',
#  '눈',
#  '밑',
#  '줄',
#  '별',
#  '하나',
#  '추억',
#  '별',
#  '하나',
#  '사랑',
#  '별',
#  '하나',
#  '별',
#  '하나',
#  '동경',
#  '별',
#  '하나',
#  '시',
#  '별',
#  '하나',
#  '어머니',
#  '당신',
#  '시',
#  '하늘',
#  '우러러',
#  '점',
#  '부끄러움',
#  '당신',
#  '삶',
#  '모든',
#  '것',
#  '사랑',
#  '수',
#  '때론',
#  '게',
#  '무기',
#  '때',
#  '당신',
#  '첩방',
#  '등불',
#  '기억',
#  '난',
#  '왜',
#  '못',
#  '용기',
#  '내지',
#  '못',
#  '뒤',
#  '그',
#  '칼',
#  '대신',
#  '연필',
#  '끝',
#  '힘',
#  '창살',
#  '건너편',
#  '하늘',
#  '별',
#  '나',
#  '이름',
#  '나',
#  '나라',
#  '오늘',
#  '흙',
#  '별',
#  '하나',
#  '추억',
#  '별',
#  '하나',
#  '사랑',
#  '별',
#  '하나',
#  '별',
#  '하나',
#  '동경',
#  '별',
#  '하나',
#  '시',
#  '별',
#  '하나',
#  '어머니',
#  '별',
#  '바람',
#  '밤',
#  '내',
#  '길',
#  '밤',
#  '기억',
#  '하늘',
#  '별',
#  '헤던',
#  '당신',
#  '밤',
#  '당신',
#  '시',
#  '하늘',
#  '우러러',
#  '점',
#  '부끄러움',
#  '당신',
#  '꿈',
#  '모든',
#  '것',
#  '사랑',
#  '수',
#  '비판',
#  '비아',
#  '입가',
#  '뒤',
#  '시대',
#  '뒤',
#  '고개',
#  '내',
#  '난',
#  '한국인',
#  '난',
#  '한국',
#  '사람',
#  '난',
#  '촛불',
#  '위',
#  '바람',
#  '이름',
#  '나라',
#  '설움',
#  '죄책감',
#  '철인',
#  '자화상',
#  '위로',
#  '덕',
#  '겨우',
#  '겨우',
#  '걸음',
#  '마',
#  '오늘',
#  '밤',
#  '당신',
#  '시가',
#  '별',
#  '광장',
#  '위',
#  '빛',
#  '빛',
#  '별',
#  '하나',
#  '추억',
#  '별',
#  '하나',
#  '사랑',
#  '별',
#  '하나',
#  '별',
#  '하나',
#  '동경',
#  '별',
#  '하나',
#  '시',
#  '별',
#  '하나',
#  '어머니',
#  '별',
#  '바람',
#  '밤',
#  '내',
#  '길',
#  '밤',
#  '기억',
#  '하늘',
#  '별',
#  '헤던',
#  '당신',
#  '밤',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '가슴속',
#  '하나',
#  '둘',
#  '별',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '알',
#  '수',
#  '위로',
#  '멍',
#  '만주',
#  '일본',
#  '삶',
#  '궤',
#  '내',
#  '맘',
#  '누구',
#  '덕',
#  '이기',
#  '나',
#  '내',
#  '나라',
#  '이름',
#  '지금',
#  '수',
#  '그대',
#  '작',
#  '명예',
#  '이',
#  '나라',
#  '시인',
#  '별',
#  '하나',
#  '추억',
#  '별',
#  '하나',
#  '사랑',
#  '별',
#  '하나',
#  '별',
#  '하나',
#  '동경',
#  '별',
#  '하나',
#  '시',
#  '별',
#  '하나',
#  '어머니',
#  '별',
#  '바람',
#  '밤',
#  '내',
#  '길',
#  '밤',
#  '기억',
#  '하늘',
#  '별',
#  '헤던',
#  '헤던',
#  '당신',
#  '밤',
#  '접기',
#  '프린트',
#  '가사',
#  '오류',
#  '신고',
#  '작사',
#  '작곡',
#  '혹시',
#  '저',
#  '별도',
#  '보고',
#  '날',
#  '보고',
#  '저',
#  '별도',
#  '보고',
#  '날',
#  '지금',
#  '날',
#  '날',
#  '피해',
#  '날',
#  '오늘',
#  '넌',
#  '더',
#  '이',
#  '밤',
#  '내겐',
#  '어',
#  '두운',
#  '밤',
#  '지나',
#  '아침',
#  '온대',
#  '구름',
#  '보이지',
#  '때',
#  '너',
#  '그',
#  '자리',
#  '걸',
#  '난',
#  '넌',
#  '내',
#  '보이지',
#  '때',
#  '항상',
#  '저',
#  '구름',
#  '이제',
#  '비',
#  '리기',
#  '나',
#  '기도',
#  '혹시',
#  '저',
#  '별도',
#  '보고',
#  '날',
#  '보고',
#  '저',
#  '별도',
#  '보고',
#  '날',
#  '지금',
#  '날',
#  '날',
#  '피해',
#  '날',
#  '너',
#  '게',
#  '또',
#  '내',
#  '노래',
#  '내',
#  '보고',
#  '게',
#  '지금',
#  '너',
#  '매일',
#  '밤',
#  ...]

# %%
words = [n for n in nouns if len(n) > 1]

# %%
cnt = Counter(words)

# %%
img = Image.open("pngwing.png")
img_array = np.array(img)

wc = WordCloud(
    font_path='AppleGothic',
    width = 400,
    height = 400,
    scale = 2.0,
    max_font_size = 250,
    max_words = 50,
    mask = img_array
)
gen = wc.generate_from_frequencies(cnt)
plt.figure()
plt.axis('off')
plt.imshow(gen)
