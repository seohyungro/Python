# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
kosdaq_c = pd.read_csv("./공모전파일/코스닥데이터(연결재무제표).csv", encoding = 'euc-kr')
kosdaq_i = pd.read_csv("./공모전파일/코스닥데이터(개별재무제표).csv", encoding = 'euc-kr')

# %%
kosdaq_c
# Out:
#            회사명  거래소코드     회계년도  매출액증가율(IFRS연결)  총자본증가율(IFRS연결)
# 0     (주)CMG제약  58820  2018/12           20.05            4.39  \
# 1     (주)CMG제약  58820  2019/12           17.56           68.07
# 2     (주)CMG제약  58820  2020/12             NaN             NaN
# 3     (주)CMG제약  58820  2021/12             NaN             NaN
# 4     (주)CMG제약  58820  2022/12             NaN             NaN
# ...        ...    ...      ...             ...             ...
# 7653   흥구석유(주)  24060  2018/12             NaN             NaN
# 7654   흥구석유(주)  24060  2019/12             NaN             NaN
# 7655   흥구석유(주)  24060  2020/12             NaN             NaN
# 7656   흥구석유(주)  24060  2021/12             NaN             NaN
# 7657   흥구석유(주)  24060  2022/12             NaN             NaN
#
#       자기자본증가율(IFRS연결)  순이익증가율(IFRS연결)  유형자산증가율(IFRS연결)  비유동자산증가율(IFRS연결)
# 0                6.16          113.94             6.71             16.47  \
# ...

# %%
kosdaq_i
# Out:
#            회사명  거래소코드     회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)
# 0     (주)CMG제약  58820  2018/12         20.05          4.39           6.16  \
# 1     (주)CMG제약  58820  2019/12         17.56         68.07          73.26
# 2     (주)CMG제약  58820  2020/12          9.96          1.62           0.54
# 3     (주)CMG제약  58820  2021/12          7.78          1.95           1.97
# 4     (주)CMG제약  58820  2022/12         18.31          7.07           0.14
# ...        ...    ...      ...           ...           ...            ...
# 7653   흥구석유(주)  24060  2018/12          6.87         -5.89           0.99
# 7654   흥구석유(주)  24060  2019/12         -9.35         11.24           9.31
# 7655   흥구석유(주)  24060  2020/12        -23.78          0.07           3.38
# 7656   흥구석유(주)  24060  2021/12         15.12         -1.28          -0.88
# 7657   흥구석유(주)  24060  2022/12         10.97         13.66           1.51
#
#       순이익증가율(IFRS)  유형자산증가율(IFRS)  비유동자산증가율(IFRS)  유동자산증가율(IFRS)  ...
# ...

# %%
# kosdaq_c.info()
#len(kosdaq_c["회사명"].unique())
#len(kosdaq_c["거래소코드"].unique())
# print('열 개수:', len(kosdaq_sp_i.columns))
# print(kosdaq_i.columns)
# pd.options.display.max_columns = 4000
# kosdaq[kosdaq.isnull().any(axis=1)]

# %%
# 코스피 상장폐지 종목
# kosdaq_sp_c = kosdaq_c.loc[~kosdaq_c['상장폐지일'].isnull()].reset_index(drop=True)
# kosdaq_sp_i = kosdaq_i.loc[~kosdaq_i['상장폐지일'].isnull()].reset_index(drop=True)

# %%
kosdaq_i.columns = ['회사명', '거래소코드', '회계년도', '매출액증가율(IFRS)', '총자본증가율(IFRS)', '자기자본증가율(IFRS)',
       '순이익증가율(IFRS)', '유형자산증가율(IFRS)', '비유동자산증가율(IFRS)', '유동자산증가율(IFRS)',
       '재고자산증가율(IFRS)', '유동비율(IFRS)', '당좌비율(IFRS)', '현금비율(IFRS)',
       '순운전자본비율(IFRS)', '부채비율(IFRS)', '자기자본배율(IFRS)', '비유동비율(IFRS)',
       '유동자산구성비율(IFRS)', '자기자본구성비율(IFRS)', '매출액총이익률(IFRS)', '매출액순이익률(IFRS)',
       '총자본사업이익률(IFRS)', '총자본순이익률(IFRS)', '자기자본순이익률(IFRS)', '1주당순이익(IFRS)(원)',
       '1주당매출액(IFRS)(원)', '총자본회전률(IFRS)', '자기자본회전률(IFRS)', '비유동자산회전률(IFRS)',
       '재고자산회전률(IFRS)', '매출채권회전률(IFRS)', '매입채무회전률(IFRS)', '매입채무회전기간(IFRS)',
       '재고자산회전기간(IFRS)', '매출채권회전기간(IFRS)', '1회전기간(IFRS)', '운전자본회전률(IFRS)',
       '순운전자본회전률(IFRS)', '유형자산회전율(IFRS)', '유동자산회전률(IFRS)', '당좌자산회전률(IFRS)',
       '부가가치(IFRS)(백만원)', '총자본투자효율(IFRS)', '설비투자효율(IFRS)', '기계투자효율(IFRS)',
       '부가가치율(IFRS)', '노동소득분배율(IFRS)', '자본분배율(IFRS)', '이윤분배율(IFRS)', '상장폐지일',
       '소속코드', '상장일']

# %%
# 1.연결재무제표를 기준으로 결측치 개별재주제표로 대체
kosdaq_c.columns = ['회사명', '거래소코드', '회계년도', '매출액증가율(IFRS)', '총자본증가율(IFRS)', '자기자본증가율(IFRS)',
       '순이익증가율(IFRS)', '유형자산증가율(IFRS)', '비유동자산증가율(IFRS)', '유동자산증가율(IFRS)',
       '재고자산증가율(IFRS)', '유동비율(IFRS)', '당좌비율(IFRS)', '현금비율(IFRS)',
       '순운전자본비율(IFRS)', '부채비율(IFRS)', '자기자본배율(IFRS)', '비유동비율(IFRS)',
       '유동자산구성비율(IFRS)', '자기자본구성비율(IFRS)', '매출액총이익률(IFRS)', '매출액순이익률(IFRS)',
       '총자본사업이익률(IFRS)', '총자본순이익률(IFRS)', '자기자본순이익률(IFRS)', '1주당순이익(IFRS)(원)',
       '1주당매출액(IFRS)(원)', '총자본회전률(IFRS)', '자기자본회전률(IFRS)', '비유동자산회전률(IFRS)',
       '재고자산회전률(IFRS)', '매출채권회전률(IFRS)', '매입채무회전률(IFRS)', '매입채무회전기간(IFRS)',
       '재고자산회전기간(IFRS)', '매출채권회전기간(IFRS)', '1회전기간(IFRS)', '운전자본회전률(IFRS)',
       '순운전자본회전률(IFRS)', '유형자산회전율(IFRS)', '유동자산회전률(IFRS)', '당좌자산회전률(IFRS)',
       '부가가치(IFRS)(백만원)', '총자본투자효율(IFRS)', '설비투자효율(IFRS)', '기계투자효율(IFRS)',
       '부가가치율(IFRS)', '노동소득분배율(IFRS)', '자본분배율(IFRS)', '이윤분배율(IFRS)', '상장폐지일',
       '소속코드', '상장일']
kosdaq = kosdaq_c.fillna(value = kosdaq_i)
kosdaq
# Out:
#            회사명  거래소코드     회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)
# 0     (주)CMG제약  58820  2018/12         20.05          4.39           6.16  \
# 1     (주)CMG제약  58820  2019/12         17.56         68.07          73.26
# 2     (주)CMG제약  58820  2020/12          9.96          1.62           0.54
# 3     (주)CMG제약  58820  2021/12          7.78          1.95           1.97
# 4     (주)CMG제약  58820  2022/12         18.31          7.07           0.14
# ...        ...    ...      ...           ...           ...            ...
# 7653   흥구석유(주)  24060  2018/12          6.87         -5.89           0.99
# 7654   흥구석유(주)  24060  2019/12         -9.35         11.24           9.31
# 7655   흥구석유(주)  24060  2020/12        -23.78          0.07           3.38
# 7656   흥구석유(주)  24060  2021/12         15.12         -1.28          -0.88
# 7657   흥구석유(주)  24060  2022/12         10.97         13.66           1.51
#
#       순이익증가율(IFRS)  유형자산증가율(IFRS)  비유동자산증가율(IFRS)  유동자산증가율(IFRS)  ...
# ...

# %%
kosdaq.isna().sum()
# Out:
# 회사명                   0
# 거래소코드                 0
# 회계년도                  0
# 매출액증가율(IFRS)        385
# 총자본증가율(IFRS)        385
# 자기자본증가율(IFRS)       385
# 순이익증가율(IFRS)        385
# 유형자산증가율(IFRS)       385
# 비유동자산증가율(IFRS)      385
# 유동자산증가율(IFRS)       385
# 재고자산증가율(IFRS)       385
# 유동비율(IFRS)          385
# 당좌비율(IFRS)          385
# 현금비율(IFRS)          385
# 순운전자본비율(IFRS)       385
# 부채비율(IFRS)          385
# 자기자본배율(IFRS)        385
# 비유동비율(IFRS)         385
# 유동자산구성비율(IFRS)      385
# 자기자본구성비율(IFRS)      385
# 매출액총이익률(IFRS)       385
# 매출액순이익률(IFRS)       385
# 총자본사업이익률(IFRS)      385
# 총자본순이익률(IFRS)       385
# 자기자본순이익률(IFRS)      385
# 1주당순이익(IFRS)(원)     385
# 1주당매출액(IFRS)(원)     385
# 총자본회전률(IFRS)        385
# 자기자본회전률(IFRS)       385
# 비유동자산회전률(IFRS)      385
# 재고자산회전률(IFRS)       385
# 매출채권회전률(IFRS)       385
# 매입채무회전률(IFRS)       385
# 매입채무회전기간(IFRS)      385
# 재고자산회전기간(IFRS)      385
# 매출채권회전기간(IFRS)      385
# 1회전기간(IFRS)         385
# 운전자본회전률(IFRS)       385
# ...

# %%
# 3. 해당년도 재무제표가 존재하지 않는 기업 해당년도 삭제
kosdaq.isna().sum()
kosdaq.dropna(subset=['매출액증가율(IFRS)'], inplace = True)
kosdaq.isna().sum()
# Out:
# 회사명                   0
# 거래소코드                 0
# 회계년도                  0
# 매출액증가율(IFRS)          0
# 총자본증가율(IFRS)          0
# 자기자본증가율(IFRS)         0
# 순이익증가율(IFRS)          0
# 유형자산증가율(IFRS)         0
# 비유동자산증가율(IFRS)        0
# 유동자산증가율(IFRS)         0
# 재고자산증가율(IFRS)         0
# 유동비율(IFRS)            0
# 당좌비율(IFRS)            0
# 현금비율(IFRS)            0
# 순운전자본비율(IFRS)         0
# 부채비율(IFRS)            0
# 자기자본배율(IFRS)          0
# 비유동비율(IFRS)           0
# 유동자산구성비율(IFRS)        0
# 자기자본구성비율(IFRS)        0
# 매출액총이익률(IFRS)         0
# 매출액순이익률(IFRS)         0
# 총자본사업이익률(IFRS)        0
# 총자본순이익률(IFRS)         0
# 자기자본순이익률(IFRS)        0
# 1주당순이익(IFRS)(원)       0
# 1주당매출액(IFRS)(원)       0
# 총자본회전률(IFRS)          0
# 자기자본회전률(IFRS)         0
# 비유동자산회전률(IFRS)        0
# 재고자산회전률(IFRS)         0
# 매출채권회전률(IFRS)         0
# 매입채무회전률(IFRS)         0
# 매입채무회전기간(IFRS)        0
# 재고자산회전기간(IFRS)        0
# 매출채권회전기간(IFRS)        0
# 1회전기간(IFRS)           0
# 운전자본회전률(IFRS)         0
# ...

# %%
kosdaq
# Out:
#            회사명  거래소코드     회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)
# 0     (주)CMG제약  58820  2018/12         20.05          4.39           6.16  \
# 1     (주)CMG제약  58820  2019/12         17.56         68.07          73.26
# 2     (주)CMG제약  58820  2020/12          9.96          1.62           0.54
# 3     (주)CMG제약  58820  2021/12          7.78          1.95           1.97
# 4     (주)CMG제약  58820  2022/12         18.31          7.07           0.14
# ...        ...    ...      ...           ...           ...            ...
# 7653   흥구석유(주)  24060  2018/12          6.87         -5.89           0.99
# 7654   흥구석유(주)  24060  2019/12         -9.35         11.24           9.31
# 7655   흥구석유(주)  24060  2020/12        -23.78          0.07           3.38
# 7656   흥구석유(주)  24060  2021/12         15.12         -1.28          -0.88
# 7657   흥구석유(주)  24060  2022/12         10.97         13.66           1.51
#
#       순이익증가율(IFRS)  유형자산증가율(IFRS)  비유동자산증가율(IFRS)  유동자산증가율(IFRS)  ...
# ...

# %%
# 4. 상장일 이전에 회계년도 데이터 삭제
kosdaq['상장일'] = pd.to_datetime(kosdaq['상장일'])
kosdaq['회계년도'] = pd.to_datetime(kosdaq['회계년도'], format='%Y/%m')
kosdaq = kosdaq.loc[kosdaq['회계년도'] >= kosdaq['상장일']]

# %%
kosdaq
# Out:
#            회사명  거래소코드       회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)
# 0     (주)CMG제약  58820 2018-12-01         20.05          4.39           6.16  \
# 1     (주)CMG제약  58820 2019-12-01         17.56         68.07          73.26
# 2     (주)CMG제약  58820 2020-12-01          9.96          1.62           0.54
# 3     (주)CMG제약  58820 2021-12-01          7.78          1.95           1.97
# 4     (주)CMG제약  58820 2022-12-01         18.31          7.07           0.14
# ...        ...    ...        ...           ...           ...            ...
# 7653   흥구석유(주)  24060 2018-12-01          6.87         -5.89           0.99
# 7654   흥구석유(주)  24060 2019-12-01         -9.35         11.24           9.31
# 7655   흥구석유(주)  24060 2020-12-01        -23.78          0.07           3.38
# 7656   흥구석유(주)  24060 2021-12-01         15.12         -1.28          -0.88
# 7657   흥구석유(주)  24060 2022-12-01         10.97         13.66           1.51
#
# ...

# %%
# 5. kosdaq, kosdaq 외국계 기업 종목코드 제거
kosdaq = kosdaq[kosdaq['거래소코드'] < 900000]
kosdaq.reset_index(drop = True)
# Out:
#            회사명  거래소코드       회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)
# 0     (주)CMG제약  58820 2018-12-01         20.05          4.39           6.16  \
# 1     (주)CMG제약  58820 2019-12-01         17.56         68.07          73.26
# 2     (주)CMG제약  58820 2020-12-01          9.96          1.62           0.54
# 3     (주)CMG제약  58820 2021-12-01          7.78          1.95           1.97
# 4     (주)CMG제약  58820 2022-12-01         18.31          7.07           0.14
# ...        ...    ...        ...           ...           ...            ...
# 6721   흥구석유(주)  24060 2018-12-01          6.87         -5.89           0.99
# 6722   흥구석유(주)  24060 2019-12-01         -9.35         11.24           9.31
# 6723   흥구석유(주)  24060 2020-12-01        -23.78          0.07           3.38
# 6724   흥구석유(주)  24060 2021-12-01         15.12         -1.28          -0.88
# 6725   흥구석유(주)  24060 2022-12-01         10.97         13.66           1.51
#
# ...

# %%
# 2. 거래소 코드 두개이상인 기업 데이터 제거
grouped = kosdaq.groupby('회사명')['거래소코드'].nunique()
result = grouped[grouped > 1].index.tolist()
len(result)
# Out:
# 13

# %%
result
# Out:
# ['(주)알로이스',
#  '(주)에스에이티',
#  '(주)엔케이맥스',
#  '(주)원바이오젠',
#  '(주)원익피앤이',
#  '(주)자비스',
#  '(주)티에스트릴리온',
#  '(주)포인트엔지니어링',
#  '(주)휴럼',
#  '에스케이오션플랜트(주)',
#  '엠에프엠코리아(주)',
#  '원텍(주)',
#  '줌인터넷(주)']

# %%
kosdaq.loc[kosdaq['회사명'] == '(주)알로이스']
# 271400, 60540, 262760, 278380, 131390, 230400,284610, 176560, 284420, 251960, 216280,25440, 229480
# Out:
#           회사명   거래소코드       회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)
# 2313  (주)알로이스  271400 2018-12-01          0.00          0.00           0.00  \
# 2315  (주)알로이스  297570 2019-12-01          0.00          0.00           0.00
# 2316  (주)알로이스  297570 2020-12-01        -15.12         19.41          20.07
# 2317  (주)알로이스  297570 2021-12-01         43.12         57.56          26.05
# 2318  (주)알로이스  297570 2022-12-01        -21.62          1.17          24.98
#
#       순이익증가율(IFRS)  유형자산증가율(IFRS)  비유동자산증가율(IFRS)  유동자산증가율(IFRS)  ...
# 2313          0.00           0.00            0.00           0.00  ...  \
# 2315          0.00           0.00            0.00           0.00  ...
# 2316          0.00         109.97          137.11          16.49  ...
# 2317         57.97         -18.33          277.15          46.47  ...
# 2318         10.87         -15.47          -28.97           5.09  ...
#
#       총자본투자효율(IFRS)  설비투자효율(IFRS)  기계투자효율(IFRS)  부가가치율(IFRS)  노동소득분배율(IFRS)
# ...

# %%
codes = [271400, 60540, 262760, 278380, 131390, 230400,284610, 176560, 284420, 251960, 216280,25440, 229480]
kosdaq.loc[~(kosdaq['거래소코드'].isin(codes))]
# Out:
#            회사명  거래소코드       회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)
# 0     (주)CMG제약  58820 2018-12-01         20.05          4.39           6.16  \
# 1     (주)CMG제약  58820 2019-12-01         17.56         68.07          73.26
# 2     (주)CMG제약  58820 2020-12-01          9.96          1.62           0.54
# 3     (주)CMG제약  58820 2021-12-01          7.78          1.95           1.97
# 4     (주)CMG제약  58820 2022-12-01         18.31          7.07           0.14
# ...        ...    ...        ...           ...           ...            ...
# 7653   흥구석유(주)  24060 2018-12-01          6.87         -5.89           0.99
# 7654   흥구석유(주)  24060 2019-12-01         -9.35         11.24           9.31
# 7655   흥구석유(주)  24060 2020-12-01        -23.78          0.07           3.38
# 7656   흥구석유(주)  24060 2021-12-01         15.12         -1.28          -0.88
# 7657   흥구석유(주)  24060 2022-12-01         10.97         13.66           1.51
#
# ...

# %%
kosdaq[kosdaq['매출액증가율(IFRS)'] == 0]
# Out:
#              회사명   거래소코드       회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)
# 19       (주)가온칩스  399720 2022-12-01           0.0           0.0  \
# 29      (주)강원에너지  114190 2022-12-01           0.0           0.0
# 36      (주)고바이오랩  348150 2020-12-01           0.0           0.0
# 42    (주)고영테크놀러지   98460 2021-12-01           0.0           0.0
# 49      (주)골드퍼시픽   38530 2018-12-01           0.0           0.0
# ...          ...     ...        ...           ...           ...
# 7614     현우산업(주)   92300 2018-12-01           0.0           0.0
# 7619     현진소재(주)   53660 2018-12-01           0.0           0.0
# 7623     화성밸브(주)   39610 2018-12-01           0.0           0.0
# 7627     화성밸브(주)   39610 2022-12-01           0.0           0.0
# 7645     휴마시스(주)  205470 2020-12-01           0.0           0.0
#
#       자기자본증가율(IFRS)  순이익증가율(IFRS)  유형자산증가율(IFRS)  비유동자산증가율(IFRS)
# 19              0.0           0.0            0.0             0.0  \
# ...

# %%
kosdaq['매출액증가율(IFRS)'] = kosdaq['매출액증가율(IFRS)'].replace(0, np.nan)
mean_growth_rate = kosdaq['매출액증가율(IFRS)'].mean()
kosdaq['매출액증가율(IFRS)'] = kosdaq['매출액증가율(IFRS)'].fillna(mean_growth_rate)
kosdaq[kosdaq['매출액증가율(IFRS)'] == 0]
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/2370139309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['매출액증가율(IFRS)'] = kosdaq['매출액증가율(IFRS)'].replace(0, np.nan)
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/2370139309.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['매출액증가율(IFRS)'] = kosdaq['매출액증가율(IFRS)'].fillna(mean_growth_rate)
# Empty DataFrame
# ...

# %%
kosdaq['총자본증가율(IFRS)'] = kosdaq['총자본증가율(IFRS)'].replace(0, np.nan)
mean_growth_rate = kosdaq['총자본증가율(IFRS)'].mean()
kosdaq['총자본증가율(IFRS)'] = kosdaq['총자본증가율(IFRS)'].fillna(mean_growth_rate)
kosdaq[kosdaq['총자본증가율(IFRS)'] == 0]
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/3031114309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['총자본증가율(IFRS)'] = kosdaq['총자본증가율(IFRS)'].replace(0, np.nan)
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/3031114309.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['총자본증가율(IFRS)'] = kosdaq['총자본증가율(IFRS)'].fillna(mean_growth_rate)
# Empty DataFrame
# ...

# %%
kosdaq['자기자본증가율(IFRS)'] = kosdaq['자기자본증가율(IFRS)'].replace(0, np.nan)
mean_growth_rate = kosdaq['자기자본증가율(IFRS)'].mean()
kosdaq['자기자본증가율(IFRS)'] = kosdaq['자기자본증가율(IFRS)'].fillna(mean_growth_rate)
kosdaq[kosdaq['자기자본증가율(IFRS)'] == 0]
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/2616909152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['자기자본증가율(IFRS)'] = kosdaq['자기자본증가율(IFRS)'].replace(0, np.nan)
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/2616909152.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['자기자본증가율(IFRS)'] = kosdaq['자기자본증가율(IFRS)'].fillna(mean_growth_rate)
# Empty DataFrame
# ...

# %%
kosdaq['순이익증가율(IFRS)'] = kosdaq['순이익증가율(IFRS)'].replace(0, np.nan)
mean_growth_rate = kosdaq['순이익증가율(IFRS)'].mean()
kosdaq['순이익증가율(IFRS)'] = kosdaq['순이익증가율(IFRS)'].fillna(mean_growth_rate)
kosdaq[kosdaq['순이익증가율(IFRS)'] == 0]
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/1395883873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['순이익증가율(IFRS)'] = kosdaq['순이익증가율(IFRS)'].replace(0, np.nan)
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/1395883873.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['순이익증가율(IFRS)'] = kosdaq['순이익증가율(IFRS)'].fillna(mean_growth_rate)
# Empty DataFrame
# ...

# %%
kosdaq['유형자산증가율(IFRS)'] = kosdaq['유형자산증가율(IFRS)'].replace(0, np.nan)
mean_growth_rate = kosdaq['유형자산증가율(IFRS)'].mean()
kosdaq['유형자산증가율(IFRS)'] = kosdaq['유형자산증가율(IFRS)'].fillna(mean_growth_rate)
kosdaq[kosdaq['유형자산증가율(IFRS)'] == 0]
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/4170220527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['유형자산증가율(IFRS)'] = kosdaq['유형자산증가율(IFRS)'].replace(0, np.nan)
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/4170220527.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['유형자산증가율(IFRS)'] = kosdaq['유형자산증가율(IFRS)'].fillna(mean_growth_rate)
# Empty DataFrame
# ...

# %%
kosdaq['비유동자산증가율(IFRS)'] = kosdaq['비유동자산증가율(IFRS)'].replace(0, np.nan)
mean_growth_rate = kosdaq['비유동자산증가율(IFRS)'].mean()
kosdaq['비유동자산증가율(IFRS)'] = kosdaq['비유동자산증가율(IFRS)'].fillna(mean_growth_rate)
kosdaq[kosdaq['비유동자산증가율(IFRS)'] == 0]
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/648894300.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['비유동자산증가율(IFRS)'] = kosdaq['비유동자산증가율(IFRS)'].replace(0, np.nan)
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/648894300.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['비유동자산증가율(IFRS)'] = kosdaq['비유동자산증가율(IFRS)'].fillna(mean_growth_rate)
# Empty DataFrame
# ...

# %%
kosdaq['유동자산증가율(IFRS)'] = kosdaq['유동자산증가율(IFRS)'].replace(0, np.nan)
mean_growth_rate = kosdaq['유동자산증가율(IFRS)'].mean()
kosdaq['유동자산증가율(IFRS)'] = kosdaq['유동자산증가율(IFRS)'].fillna(mean_growth_rate)
kosdaq[kosdaq['유동자산증가율(IFRS)'] == 0]
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/2147799870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['유동자산증가율(IFRS)'] = kosdaq['유동자산증가율(IFRS)'].replace(0, np.nan)
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/2147799870.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['유동자산증가율(IFRS)'] = kosdaq['유동자산증가율(IFRS)'].fillna(mean_growth_rate)
# Empty DataFrame
# ...

# %%
kosdaq['재고자산증가율(IFRS)'] = kosdaq['재고자산증가율(IFRS)'].replace(0, np.nan)
mean_growth_rate = kosdaq['재고자산증가율(IFRS)'].mean()
kosdaq['재고자산증가율(IFRS)'] = kosdaq['재고자산증가율(IFRS)'].fillna(mean_growth_rate)
kosdaq[kosdaq['매출액증가율(IFRS)'] == 0]
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/1057369221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['재고자산증가율(IFRS)'] = kosdaq['재고자산증가율(IFRS)'].replace(0, np.nan)
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/1057369221.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq['재고자산증가율(IFRS)'] = kosdaq['재고자산증가율(IFRS)'].fillna(mean_growth_rate)
# Empty DataFrame
# ...

# %%
kosdaq['매출액증가율(IFRS)']

q5 = np.percentile(kosdaq['매출액증가율(IFRS)'], 5)
q95 = np.percentile(kosdaq['매출액증가율(IFRS)'], 95)

outliers = kosdaq['매출액증가율(IFRS)'][(kosdaq['매출액증가율(IFRS)'] < q5) | (kosdaq['매출액증가율(IFRS)'] > q95)]

print("하위 5%:", q5)
print("상위 5%:", q95)
print("이상치:", outliers)
# Out:
# 하위 5%: -40.24
# 상위 5%: 78.58500000000001
# 이상치: 7        84.57
# 26      -50.47
# 38      301.12
# 46      -45.85
# 47      226.35
#          ...
# 7636     91.21
# 7638    -57.02
# 7639    -42.66
# 7642     80.87
# 7646    603.96
# Name: 매출액증가율(IFRS), Length: 674, dtype: float64

# %%
def windsorize(data, lower_percentile=0.05, upper_percentile=0.95):
    if isinstance(data, pd.Series):
        data = pd.DataFrame(data)
    numeric_df = data.select_dtypes(include=np.number)
    lower_bound = np.percentile(numeric_df, lower_percentile * 100)
    upper_bound = np.percentile(numeric_df, upper_percentile * 100)
    windsorized_data = np.where(numeric_df < lower_bound, lower_bound, numeric_df)
    windsorized_data = np.where(windsorized_data > upper_bound, upper_bound, windsorized_data)
    return windsorized_data

# %%
for i in range(3, 50, 1):
    kosdaq[kosdaq.columns[i]] = windsorize(kosdaq[kosdaq.columns[i]])
# Out:
# /var/folders/xs/8nhrbkk97jzf2f4zjswkk0b80000gn/T/ipykernel_2055/3554770679.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kosdaq[kosdaq.columns[i]] = windsorize(kosdaq[kosdaq.columns[i]])

# %%
kosdaq['매출액증가율(IFRS)']

q5 = np.percentile(kosdaq['매출액증가율(IFRS)'], 5)
q95 = np.percentile(kosdaq['매출액증가율(IFRS)'], 95)

outliers = kosdaq['매출액증가율(IFRS)'][(kosdaq['매출액증가율(IFRS)'] < q5) | (kosdaq['매출액증가율(IFRS)'] > q95)]

print("하위 5%:", q5)
print("상위 5%:", q95)
print("이상치:", outliers)
# Out:
# 하위 5%: -40.2325
# 상위 5%: 78.53625000000001
# 이상치: 7       78.585
# 26     -40.240
# 38      78.585
# 46     -40.240
# 47      78.585
#          ...
# 7636    78.585
# 7638   -40.240
# 7639   -40.240
# 7642    78.585
# 7646    78.585
# Name: 매출액증가율(IFRS), Length: 674, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
numeric_cols = kosdaq.select_dtypes(include=np.number).columns
scaler = StandardScaler()
kosdaq[numeric_cols] = scaler.fit_transform(kosdaq[numeric_cols])

print(kosdaq.head())
# Out:
#         회사명     거래소코드       회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)
# 0  (주)CMG제약 -0.640375 2018-12-01      0.266275     -0.331405      -0.251297  \
# 1  (주)CMG제약 -0.640375 2019-12-01      0.181833      2.456886       2.086615
# 2  (주)CMG제약 -0.640375 2020-12-01     -0.075901     -0.452692      -0.447110
# 3  (주)CMG제약 -0.640375 2021-12-01     -0.149830     -0.438243      -0.397286
# 4  (주)CMG제약 -0.640375 2022-12-01      0.207267     -0.214059      -0.461047
#
#    순이익증가율(IFRS)  유형자산증가율(IFRS)  비유동자산증가율(IFRS)  유동자산증가율(IFRS)  ...
# 0      1.374069      -0.273917        0.036875      -0.408098  ...  \
# 1     -1.292267       0.609086        0.345226       2.118952  ...
# 2     -1.873791       0.170799        0.101841      -0.504559  ...
# 3      2.841710      -0.383757        1.075698      -0.831456  ...
# 4      0.117328       0.156868       -0.291758      -0.185998  ...
#
#    총자본투자효율(IFRS)  설비투자효율(IFRS)  기계투자효율(IFRS)  부가가치율(IFRS)  노동소득분배율(IFRS)
# ...

# %%
kosdaq[numeric_cols].mean()
# Out:
# 거래소코드              7.183602e-17
# 매출액증가율(IFRS)      -4.331289e-17
# 총자본증가율(IFRS)       4.120007e-17
# 자기자본증가율(IFRS)      4.225648e-18
# 순이익증가율(IFRS)       1.690259e-17
# 유형자산증가율(IFRS)      5.282060e-17
# 비유동자산증가율(IFRS)     2.957954e-17
# 유동자산증가율(IFRS)     -2.324106e-17
# 재고자산증가율(IFRS)     -5.070778e-17
# 유동비율(IFRS)         5.493343e-17
# 당좌비율(IFRS)        -3.803083e-17
# 현금비율(IFRS)         1.183181e-16
# 순운전자본비율(IFRS)      2.957954e-17
# 부채비율(IFRS)         9.402067e-17
# 자기자본배율(IFRS)       1.066976e-16
# 비유동비율(IFRS)        2.112824e-16
# 유동자산구성비율(IFRS)    -1.563490e-16
# 자기자본구성비율(IFRS)     4.109443e-16
# 매출액총이익률(IFRS)      2.112824e-16
# 매출액순이익률(IFRS)     -1.478977e-17
# 총자본사업이익률(IFRS)     1.056412e-17
# 총자본순이익률(IFRS)     -6.866678e-18
# 자기자본순이익률(IFRS)    -3.591801e-17
# 1주당순이익(IFRS)(원)    2.112824e-18
# 1주당매출액(IFRS)(원)    4.225648e-17
# 총자본회전률(IFRS)       2.133952e-16
# 자기자본회전률(IFRS)     -3.591801e-17
# 비유동자산회전률(IFRS)     1.341643e-16
# 재고자산회전률(IFRS)     -2.112824e-17
# ...

# %%
kosdaq[numeric_cols].std()
# Out:
# 거래소코드              1.000074
# 매출액증가율(IFRS)       1.000074
# 총자본증가율(IFRS)       1.000074
# 자기자본증가율(IFRS)      1.000074
# 순이익증가율(IFRS)       1.000074
# 유형자산증가율(IFRS)      1.000074
# 비유동자산증가율(IFRS)     1.000074
# 유동자산증가율(IFRS)      1.000074
# 재고자산증가율(IFRS)      1.000074
# 유동비율(IFRS)         1.000074
# 당좌비율(IFRS)         1.000074
# 현금비율(IFRS)         1.000074
# 순운전자본비율(IFRS)      1.000074
# 부채비율(IFRS)         1.000074
# 자기자본배율(IFRS)       1.000074
# 비유동비율(IFRS)        1.000074
# 유동자산구성비율(IFRS)     1.000074
# 자기자본구성비율(IFRS)     1.000074
# 매출액총이익률(IFRS)      1.000074
# 매출액순이익률(IFRS)      1.000074
# 총자본사업이익률(IFRS)     1.000074
# 총자본순이익률(IFRS)      1.000074
# 자기자본순이익률(IFRS)     1.000074
# 1주당순이익(IFRS)(원)    1.000074
# 1주당매출액(IFRS)(원)    1.000074
# 총자본회전률(IFRS)       1.000074
# 자기자본회전률(IFRS)      1.000074
# 비유동자산회전률(IFRS)     1.000074
# 재고자산회전률(IFRS)      1.000074
# 매출채권회전률(IFRS)      1.000074
# 매입채무회전률(IFRS)      1.000074
# 매입채무회전기간(IFRS)     1.000074
# 재고자산회전기간(IFRS)     1.000074
# ...
