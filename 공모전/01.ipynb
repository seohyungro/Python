# %%
import pandas as pd
import numpy as np

# %%
kospi = pd.read_csv("./공모전파일/코스피.csv", encoding = 'euc-kr')
kosdaq = pd.read_csv("./공모전파일/코스닥.csv", encoding = 'euc-kr')

# %%
kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3692 entries, 0 to 3691
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   회사명            3692 non-null   object
#  1   거래소코드          3692 non-null   int64
#  2   회계년도           3692 non-null   object
#  3   상장폐지일          39 non-null     object
#  4   소속코드           3692 non-null   int64
#  5   상장일            3692 non-null   object
#  6   매출액증가율(IFRS)   3653 non-null   float64
#  7   자기자본증가율(IFRS)  3653 non-null   float64
#  8   순이익증가율(IFRS)   3653 non-null   float64
#  9   총자본증가율(IFRS)   3653 non-null   float64
#  10  매출액순이익률(IFRS)  3653 non-null   float64
#  11  부채비율(IFRS)     3653 non-null   float64
#  12  총자본순이익률(IFRS)  3653 non-null   float64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 375.1+ KB

# %%
len(kospi["회사명"].unique())
# Out:
# 753

# %%
len(kospi["거래소코드"].unique())
# Out:
# 753

# %%
kospi.head()
# Out:
#         회사명  거래소코드     회계년도 상장폐지일  소속코드         상장일  매출액증가율(IFRS)
# 0  (주)DB하이텍    990  2018/12   NaN     1  1975/12/12         -1.54  \
# 1  (주)DB하이텍    990  2019/12   NaN     1  1975/12/12         20.64
# 2  (주)DB하이텍    990  2020/12   NaN     1  1975/12/12         15.92
# 3  (주)DB하이텍    990  2021/12   NaN     1  1975/12/12         29.78
# 4  (주)DB하이텍    990  2022/12   NaN     1  1975/12/12         37.92
#
#    자기자본증가율(IFRS)  순이익증가율(IFRS)  총자본증가율(IFRS)  매출액순이익률(IFRS)  부채비율(IFRS)
# 0          22.88         27.80          7.48          14.21       93.66  \
# 1          18.94         27.42          3.68          15.01       68.82
# 2          23.23         36.73          8.25          17.70       48.29
# 3          39.07         91.31         31.29          26.09       39.99
# 4          48.04         76.24         36.93          33.34       29.48
#
#    총자본순이익률(IFRS)
# 0           9.38
# 1          11.32
# 2          14.60
# 3          23.24
# 4          30.45

# %%
# 코스피 상장폐지 종목
kospi_sp_c = kospi.loc[~kospi['상장폐지일'].isnull()].reset_index(drop=True)

# %%
kospi_sp_c
# Out:
#                회사명   거래소코드     회계년도       상장폐지일  소속코드         상장일
# 0          (주)동성화학    5190  2018/12  2021/04/16     4  1988/07/01  \
# 1          (주)동성화학    5190  2019/12  2021/04/16     4  1988/07/01
# 2          (주)동성화학    5190  2020/12  2021/04/16     4  1988/07/01
# 3        (주)부산도시가스   15350  2018/12  2022/01/18     4  1997/06/23
# 4        (주)부산도시가스   15350  2019/12  2022/01/18     4  1997/06/23
# 5        (주)부산도시가스   15350  2020/12  2022/01/18     4  1997/06/23
# 6          (주)사조해표   79660  2018/12  2019/06/26     4  2004/09/21
# 7            (주)신한    5450  2018/12  2020/06/30     4  1978/07/28
# 8            (주)신한    5450  2019/12  2020/06/30     4  1978/07/28
# 9         (주)엔에스쇼핑  138250  2018/12  2022/03/22     4  2015/03/27
# 10        (주)엔에스쇼핑  138250  2019/12  2022/03/22     4  2015/03/27
# 11        (주)엔에스쇼핑  138250  2020/12  2022/03/22     4  2015/03/27
# 12        (주)엔에스쇼핑  138250  2021/12  2022/03/22     4  2015/03/27
# ...

# %%
len(kosdaq["회사명"].unique())
# Out:
# 1605

# %%
len(kosdaq["거래소코드"].unique())
# Out:
# 1622

# %%
# 코스닥 상장폐지 종목
kosdaq_sp_c = kosdaq.loc[~kosdaq['상장폐지일'].isnull()].reset_index(drop=True)

# %%
len(kosdaq_sp_c['회사명'].unique())
# Out:
# 109

# %%
len(kosdaq_sp_c['거래소코드'].unique())
# Out:
# 109

# %%
len(kospi_sp_c['회사명'].unique())
# Out:
# 16

# %%
len(kospi_sp_c['거래소코드'].unique())
# Out:
# 16

# %%
kosdaq_sp_c
# Out:
#            회사명   거래소코드     회계년도       상장폐지일  소속코드         상장일  매출액증가율(IFRS)
# 0      (주)구스앤홈  329050  2018/12  2021/04/13     4  2019/07/12           NaN  \
# 1      (주)구스앤홈  329050  2019/12  2021/04/13     4  2019/07/12           NaN
# 2      (주)구스앤홈  329050  2020/12  2021/04/13     4  2019/07/12           NaN
# 3        (주)금빛   45890  2018/12  2021/12/20     4  2005/11/28        -23.42
# 4        (주)금빛   45890  2019/12  2021/12/20     4  2005/11/28          9.61
# ..         ...     ...      ...         ...   ...         ...           ...
# 265  현대정보기술(주)   26180  2018/12  2019/07/17     4  2000/08/08         -4.46
# 266    현진소재(주)   53660  2018/12  2022/04/26     4  2002/02/15        -12.01
# 267    현진소재(주)   53660  2019/12  2022/04/26     4  2002/02/15        -14.08
# 268    현진소재(주)   53660  2020/12  2022/04/26     4  2002/02/15        -87.18
# 269    현진소재(주)   53660  2021/12  2022/04/26     4  2002/02/15         -1.01
#
# ...

# %% [markdown]
# 연결 결측치에 개별 결측치 넣기 연ㅕ
